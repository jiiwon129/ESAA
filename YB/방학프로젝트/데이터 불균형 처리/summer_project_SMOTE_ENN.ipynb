# %% [markdown]
# # DATA LOAD

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
from sklearn.metrics import f1_score
import warnings
# %matplotlib inline

warnings.filterwarnings('ignore')

# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.4.0-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.16.4-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.41)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.14.1)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.3)
# Downloading optuna-4.4.0-py3-none-any.whl (395 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 395.9/395.9 kB 8.6 MB/s eta 0:00:00
# Downloading alembic-1.16.4-py3-none-any.whl (247 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.0/247.0 kB 13.7 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, alembic, optuna
# Successfully installed alembic-1.16.4 colorlog-6.9.0 optuna-4.4.0

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.8-cp311-cp311-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.11/dist-packages (from catboost) (0.21)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from catboost) (2.0.2)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.11/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from catboost) (1.15.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (3.2.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->catboost) (8.5.0)
# Downloading catboost-1.2.8-cp311-cp311-manylinux2014_x86_64.whl (99.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 MB 6.8 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.8

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train_df = pd.read_csv('/content/drive/MyDrive/ESAA YB/0_Summer_project/train.csv')
test_df = pd.read_csv('/content/drive/MyDrive/ESAA YB/0_Summer_project/test.csv')

# %%
train_df.head()
# Out:
#             ID         ip_src  port_src          ip_dst  port_dst protocol  \
# 0  TRAIN_00000  192.168.10.18    3721.0  192.168.10.243      55.0      UDP
# 1  TRAIN_00001   192.168.10.5       NaN             NaN      91.0      TCP
# 2  TRAIN_00002   172.16.0.182       NaN   192.168.10.18      83.0      TCP
# 3  TRAIN_00003            NaN   47668.0   192.168.10.18       NaN      TCP
# 4  TRAIN_00004   192.168.10.5   51753.0   151.101.2.116     451.0      TCP
#
#      duration  pkt_count_fwd  pkt_count_bwd  rate_fwd_pkts  ...  \
# 0    0.000231              2              2    8656.974200  ...
# 1    0.000000              0              1       0.000000  ...
# 2    0.606002             11              5      18.151760  ...
# 3    1.003829              6              6       5.977114  ...
# 4  181.195271             62             89            NaN  ...
#
#    rate_bwd_bytes  payload_fwd_mean  payload_bwd_mean  tcp_win_fwd_init  \
# 0    1.142721e+06         81.000000         81.000000                 0
# 1    0.000000e+00          0.000000          0.000000                 0
# 2    1.913360e+04        790.125000        790.125000             29200
# 3    1.155077e+04        993.416667        993.416667             29200
# 4    6.896758e+02               NaN               NaN              8192
#
#    tcp_win_bwd_init  tcp_syn_count  tcp_psh_count  tcp_rst_count  \
# 0                 0              0              0              0
# 1             16392              0              0              0
# 2             28960              2              4              1
# 3             28960              3              2              0
# 4             29200              2             22              0
#
#    iat_avg_packets  attack_type
# 0              NaN       Benign
# 1     1.499097e+09       Benign
# 2     4.040012e-02         Hulk
# 3     9.125718e-02         Hulk
# 4              NaN       Benign
#
# [5 rows x 22 columns]

# %%
test_df.head()
# Out:
#           ID          ip_src  port_src          ip_dst  port_dst protocol  \
# 0  TEST_0000  192.168.10.243   61955.0  192.168.10.249      55.0      UDP
# 1  TEST_0001             NaN   53118.0             NaN    2094.0      TCP
# 2  TEST_0002   192.168.10.43       NaN             NaN      51.0      UDP
# 3  TEST_0003  192.168.10.243   62431.0  192.168.10.249      61.0      UDP
# 4  TEST_0004             NaN   62365.0  192.168.10.249      56.0      UDP
#
#      duration  pkt_count_fwd  pkt_count_bwd  rate_fwd_pkts  ...  \
# 0  351.844741              3              3            NaN  ...
# 1    0.000063              1              1   15887.515152  ...
# 2    0.060045              2              2      33.308350  ...
# 3         NaN              2              2       0.008455  ...
# 4    0.095316              1              1      10.491425  ...
#
#    rate_fwd_bytes  rate_bwd_bytes  payload_fwd_mean  payload_bwd_mean  \
# 0        0.409271        0.719067               NaN               NaN
# 1        0.000000        0.000000              0.00              0.00
# 2     1299.025647     2231.659444             53.00             53.00
# 3        0.384714        0.930079             77.75             77.75
# 4      482.605567     1363.885298             88.00             88.00
#
#    tcp_win_fwd_init  tcp_win_bwd_init  tcp_syn_count  tcp_psh_count  \
# 0                 0                 0              0              0
# 1             29200                 0              1              0
# 2                 0                 0              0              0
# 3                 0                 0              0              0
# 4                 0                 0              0              0
#
#    tcp_rst_count  iat_avg_packets
# 0              0              NaN
# 1              1              NaN
# 2              0         0.020015
# 3              0        78.846374
# 4              0              NaN
#
# [5 rows x 21 columns]

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11999 entries, 0 to 11998
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                11999 non-null  object
#  1   ip_src            9487 non-null   object
#  2   port_src          8625 non-null   float64
#  3   ip_dst            10695 non-null  object
#  4   port_dst          9712 non-null   float64
#  5   protocol          11999 non-null  object
#  6   duration          10925 non-null  float64
#  7   pkt_count_fwd     11999 non-null  int64
#  8   pkt_count_bwd     11999 non-null  int64
#  9   rate_fwd_pkts     10828 non-null  float64
#  10  rate_bwd_pkts     10312 non-null  float64
#  11  rate_fwd_bytes    11999 non-null  float64
#  12  rate_bwd_bytes    11999 non-null  float64
#  13  payload_fwd_mean  10214 non-null  float64
#  14  payload_bwd_mean  10214 non-null  float64
#  15  tcp_win_fwd_init  11999 non-null  int64
#  16  tcp_win_bwd_init  11999 non-null  int64
#  17  tcp_syn_count     11999 non-null  int64
#  18  tcp_psh_count     11999 non-null  int64
#  19  tcp_rst_count     11999 non-null  int64
#  20  iat_avg_packets   9239 non-null   float64
#  21  attack_type       11999 non-null  object
# dtypes: float64(10), int64(7), object(5)
# memory usage: 2.0+ MB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                3000 non-null   object
#  1   ip_src            2363 non-null   object
#  2   port_src          2175 non-null   float64
#  3   ip_dst            2655 non-null   object
#  4   port_dst          2438 non-null   float64
#  5   protocol          3000 non-null   object
#  6   duration          2725 non-null   float64
#  7   pkt_count_fwd     3000 non-null   int64
#  8   pkt_count_bwd     3000 non-null   int64
#  9   rate_fwd_pkts     2672 non-null   float64
#  10  rate_bwd_pkts     2588 non-null   float64
#  11  rate_fwd_bytes    3000 non-null   float64
#  12  rate_bwd_bytes    3000 non-null   float64
#  13  payload_fwd_mean  2536 non-null   float64
#  14  payload_bwd_mean  2536 non-null   float64
#  15  tcp_win_fwd_init  3000 non-null   int64
#  16  tcp_win_bwd_init  3000 non-null   int64
#  17  tcp_syn_count     3000 non-null   int64
#  18  tcp_psh_count     3000 non-null   int64
#  19  tcp_rst_count     3000 non-null   int64
#  20  iat_avg_packets   2311 non-null   float64
# dtypes: float64(10), int64(7), object(4)
# memory usage: 492.3+ KB

# %% [markdown]
# # 전처리

# %%
train = train_df.copy() ## 데이터 복사
test = test_df.copy()

# %% [markdown]
# ## payload 결측치 관련 파생변수

# %%
# payload 결측치 플래그
train['payload_bwd_missing_flag'] = train['payload_bwd_mean'].isna().astype(int)
test['payload_bwd_missing_flag'] = test['payload_bwd_mean'].isna().astype(int)

# %% [markdown]
# ## 결측치 처리

# %%
#=============================================================================
# 포트 변수 변수 => -1
# payload, rate, iat_avg_packets, duration, => 중앙값
#=============================================================================

train['port_src'].fillna(-1, inplace=True) # -1 대체
train['port_dst'].fillna(-1, inplace=True)

payload_bwd_median = train['payload_bwd_mean'].median() # 중앙값 대체
train['payload_bwd_mean'].fillna(payload_bwd_median, inplace=True)

payload_fwd_median = train['payload_fwd_mean'].median()
train['payload_fwd_mean'].fillna(payload_fwd_median, inplace=True)

iat_median = train['iat_avg_packets'].median()
train['iat_avg_packets'].fillna(iat_median, inplace=True)

duration_median = train['duration'].median()
train['duration'].fillna(duration_median, inplace=True)

rate_fwd_median = train['rate_fwd_pkts'].median()
train['rate_fwd_pkts'].fillna(rate_fwd_median, inplace=True)

rate_bwd_median = train['rate_bwd_pkts'].median()
train['rate_bwd_pkts'].fillna(rate_bwd_median, inplace=True)

# %%
test['port_src'].fillna(-1, inplace=True) # -1 대체
test['port_dst'].fillna(-1, inplace=True)

payload_bwd_median = test['payload_bwd_mean'].median() # 중앙값 대체
test['payload_bwd_mean'].fillna(payload_bwd_median, inplace=True)

payload_fwd_median = test['payload_fwd_mean'].median()
test['payload_fwd_mean'].fillna(payload_fwd_median, inplace=True)

iat_median = test['iat_avg_packets'].median()
test['iat_avg_packets'].fillna(iat_median, inplace=True)

duration_median = test['duration'].median()
test['duration'].fillna(duration_median, inplace=True)

rate_fwd_median = test['rate_fwd_pkts'].median()
test['rate_fwd_pkts'].fillna(rate_fwd_median, inplace=True)

rate_bwd_median = test['rate_bwd_pkts'].median()
test['rate_bwd_pkts'].fillna(rate_bwd_median, inplace=True)

# %% [markdown]
# ## 값 기반 범주화 (syn_flag_cat, port_dst_cat)

# %%
#=============================================================================
# tcp_syn_count => 3개로 범주화
# port_dst => 1~2023/이후 상위 5개/나머지
#=============================================================================

def categorize_syn(x):
    if x == 0:
        return 0  # 정상
    elif x in [1, 2]:
        return 1  # 약간의 SYN 요청
    else:
        return 2  # SYN Flooding 가능성

train['syn_flag_cat'] = train['tcp_syn_count'].apply(categorize_syn)
test['syn_flag_cat'] = test['tcp_syn_count'].apply(categorize_syn)

# %%
# port_dst>1023 데이터 중 상위 5개 포트 추출
dst_port_high = train[train['port_dst'] > 1023]['port_dst']
top5_ports = dst_port_high.value_counts().nlargest(5).index

def categorize_port_dst(p):
    if p <= 1023:
        return str(int(p))  # 0~1023은 그대로
    elif p in top5_ports:
        return f'special_{int(p)}' # 1024, 8072, 49152, 8079, 2602
    else:
        return 'other'

train['port_dst_cat'] = train['port_dst'].apply(categorize_port_dst)

# %%
dst_port_high_test = test[test['port_dst'] > 1023]['port_dst']
top5_ports_test = dst_port_high_test.value_counts().nlargest(5).index

def categorize_port_dst_test(p):
    if p <= 1023:
        return str(int(p))  # 0~1023은 그대로
    elif p in top5_ports_test:
        return f'special_{int(p)}' # 1024, 8072, 49152, 8079, 2602
    else:
        return 'other'

test['port_dst_cat'] = test['port_dst'].apply(categorize_port_dst_test)

# %% [markdown]
# ## 추가 파생변수

# %%
# PSH 유무: tcp_psh_count > 0 → 1, else → 0
train['has_psh_flag'] = (train['tcp_psh_count'] > 0).astype(int)
test['has_psh_flag'] = (test['tcp_psh_count'] > 0).astype(int)

# 초당 패킷 전송 비율 = rate_fwd_pkts / rate_bwd_pkts
train['rate_pkts_ratio'] = train['rate_fwd_pkts'] / (train['rate_bwd_pkts'] + 1e-5) # 0으로 나누는 것 방지
test['rate_pkts_ratio'] = test['rate_fwd_pkts'] / (test['rate_bwd_pkts'] + 1e-5)

# 송수신 패킷 비율 = pkt_count_fwd / pkt_count_bwd
train['pkt_count_ratio'] = train['pkt_count_fwd'] / (train['pkt_count_bwd'] + 1e-5)
test['pkt_count_ratio'] = test['pkt_count_fwd'] / (test['pkt_count_bwd'] + 1e-5)

# 패킷 간 평균 시간 간격 이진 파생변수: iat_avg_packets <= 1 → 1, else → 0
train['is_iat_low'] = (train['iat_avg_packets'] <= 1.0).astype(int)
test['is_iat_low'] = (test['iat_avg_packets'] <= 1.0).astype(int)

train.drop(['tcp_psh_count','rate_fwd_pkts','rate_bwd_pkts',
            'pkt_count_fwd','pkt_count_bwd'], axis=1, inplace=True) ## 불필요한 기존변수삭제
test.drop(['tcp_psh_count','rate_fwd_pkts','rate_bwd_pkts',
            'pkt_count_fwd','pkt_count_bwd'], axis=1, inplace=True)

# %% [markdown]
# ## 변수 삭제

# %%
#=============================================================================
# ID, ip_scr, ip_dst, port_src
# payload_fwd_mean (bwd와 겹치는 칼럼)
#=============================================================================

train.drop(['ID','ip_src','ip_dst','payload_fwd_mean','port_src','port_dst','tcp_syn_count'], axis=1, inplace=True)
test.drop(['ID','ip_src','ip_dst','payload_fwd_mean','port_src','port_dst','tcp_syn_count'], axis=1, inplace=True)

# %% [markdown]
# ## 로그변환

# %%
import numpy as np

log_cols = [
    'duration',
    'rate_fwd_bytes',
    'rate_bwd_bytes',
    'payload_bwd_mean',
    'tcp_rst_count',
    'tcp_win_fwd_init',
    'tcp_win_bwd_init',
    'iat_avg_packets',
    'rate_pkts_ratio',
    'pkt_count_ratio' # 파생변수 포함
]

for col in log_cols:
    train[col] = np.log1p(train[col])

for col in log_cols:
    test[col] = np.log1p(test[col])

# %% [markdown]
# ## 스케일링

# %%
from sklearn.preprocessing import StandardScaler

scale_cols = [
    'duration',
    'rate_fwd_bytes',
    'rate_bwd_bytes',
    'payload_bwd_mean',
    'tcp_rst_count',
    'tcp_win_fwd_init',
    'tcp_win_bwd_init',
    'iat_avg_packets',
    'rate_pkts_ratio',
    'pkt_count_ratio'
]

# 스케일러 객체 생성
scaler = StandardScaler()

# 스케일링 적용
train[scale_cols] = scaler.fit_transform(train[scale_cols])
test[scale_cols] = scaler.transform(test[scale_cols])

# %% [markdown]
# ## LabelEncoding

# %%
from sklearn.preprocessing import LabelEncoder

# 라벨 인코더 생성
le_protocol = LabelEncoder()
le_postdst = LabelEncoder()
le_attack = LabelEncoder()

le_protocol.fit(pd.concat([train['protocol'], test['protocol']], axis=0).astype(str).unique())
le_postdst.fit(pd.concat([train['port_dst_cat'], test['port_dst_cat']], axis=0).astype(str).unique())

train['protocol'] = le_protocol.transform(train['protocol'].astype(str))
train['port_dst_cat'] = le_postdst.transform(train['port_dst_cat'].astype(str))
train['attack_type'] = le_attack.fit_transform(train['attack_type']) # attack_type is only in train

test['protocol'] = le_protocol.transform(test['protocol'].astype(str))
test['port_dst_cat'] = le_postdst.transform(test['port_dst_cat'].astype(str))

# %% [markdown]
# ## X, Y 데이터 분리

# %%
# Features
X = train.drop('attack_type',axis=1)

# Target
y = train['attack_type'].values

# %%
# import Library
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=156)

# %% [markdown]
# ## SMOTE + ENN

# %%
# Import Libraries
from imblearn.combine import SMOTEENN
from imblearn.over_sampling import SMOTE

resampler = SMOTEENN(random_state=156, smote=SMOTE(k_neighbors=3))

X_resampled, y_resampled = resampler.fit_resample(X_train, y_train)

# %% [markdown]
# # 모델링

# %% [markdown]
# ## RandomForest

# %%
# Import Library
from sklearn.ensemble import RandomForestClassifier

# --------------------------------------------------------------------------------

# RandomForestClassifier 객체 생성
rf = RandomForestClassifier(n_estimators=100, random_state=156, n_jobs=-1)

# 학습 및 예측
rf.fit(X_resampled, y_resampled)
pred_rf = rf.predict(X_val)

print(f'랜덤포레스트 Macro F1 Score: {f1_score(y_val, pred_rf, average="macro"):.4f}')
# Out:
# 랜덤포레스트 Macro F1 Score: 0.6267

# %%
# 피처 중요도 추출
ftr_importances_values = rf.feature_importances_
ftr_importances = pd.Series(ftr_importances_values, index=X_train.columns)
ftr_top = ftr_importances.sort_values(ascending=False)

# 피처 중요도 시각화
plt.figure(figsize=(8,6))
plt.title('Feature importances')
sns.barplot(x=ftr_top, y=ftr_top.index)
plt.show()

# %% [markdown]
# ### GridSearchCV를 이용한 하이퍼파라미터 튜닝

# %%
from sklearn.model_selection import GridSearchCV, StratifiedKFold

# --------------------------------------------------------------------------------

skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=156)

param_grid = {
    'max_depth': [5, 10, 15],
    'n_estimators': [100, 200],
    'min_samples_leaf': [1, 5, 10],
    'min_samples_split': [2, 8, 16]
}
grid = GridSearchCV(RandomForestClassifier(random_state=156, n_jobs=-1), param_grid, cv=5)
grid.fit(X_resampled, y_resampled)

# 최적 파라미터로 모델 생성
rf_best = RandomForestClassifier(**grid.best_params_, random_state=156, n_jobs=-1)

rf_best.fit(X_resampled, y_resampled)
pred_rf_best = rf_best.predict(X_val)

print(f'랜덤포레스트 Macro F1 Score: {f1_score(y_val, pred_rf_best, average="macro"):.4f}')
# Out:
# 랜덤포레스트 Macro F1 Score: 0.6495

# %%
# 피처 중요도 추출
ftr_importances_values = rf_best.feature_importances_
ftr_importances = pd.Series(ftr_importances_values, index=X_train.columns)
ftr_top = ftr_importances.sort_values(ascending=False)

# 피처 중요도 시각화
plt.figure(figsize=(8,6))
plt.title('Feature importances')
sns.barplot(x=ftr_top, y=ftr_top.index)
plt.show()

# %% [markdown]
# ## XGBoost

# %%
# Import Library
import xgboost as xgb
from xgboost import XGBClassifier

# --------------------------------------------------------------------------------

# XGBoostClassifier 객체 생성
xgb = XGBClassifier(n_estimators=300, learning_rate=0.05,
                    random_state=156, n_jobs=-1)

# 학습 및 예측
xgb.fit(X_resampled, y_resampled)
pred_xgb = xgb.predict(X_val)

print(f'XGBoost Macro F1 Score: {f1_score(y_val, pred_xgb, average="macro"):.4f}')
# Out:
# XGBoost Macro F1 Score: 0.6946

# %%
# Import Library
from xgboost import plot_importance

# 피처 중요도 시각화
plt.figure(figsize=(8,6))
plot_importance(xgb)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='F score', ylabel='Features'>

# %% [markdown]
# ## LightGBM

# %%
# Import Library
from lightgbm import LGBMClassifier

# --------------------------------------------------------------------------------

# LightGBM 객체 생성
lgbm = LGBMClassifier(n_estimators=300, learning_rate=0.05,
                      random_state=156, n_jobs=-1, verbose=0)

# 학습 및 예측
lgbm.fit(X_resampled, y_resampled)
pred_lgbm = lgbm.predict(X_val)

print(f'LightGBM Macro F1 Score: {f1_score(y_val, pred_lgbm, average="macro"):.4f}')
# Out:
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# LightGBM Macro F1 Score: 0.7046

# %%
# 피처 중요도 추출
ftr_importances_values = lgbm.feature_importances_
ftr_importances = pd.Series(ftr_importances_values, index=X_train.columns)
ftr_top = ftr_importances.sort_values(ascending=False)

# 피처 중요도 시각화
plt.figure(figsize=(8,6))
plt.title('Feature importances')
sns.barplot(x=ftr_top, y=ftr_top.index)
plt.show()

# %% [markdown]
# ## CatBoost

# %%
# Import Library
from catboost import CatBoostClassifier, Pool

# --------------------------------------------------------------------------------

# CatBoost 객체 생성
cat = CatBoostClassifier(n_estimators=300, learning_rate=0.05, random_state=156)

# 학습 및 예측
cat.fit(X_resampled, y_resampled)
pred_cat = cat.predict(X_val)

print(f'CatBoost Macro F1 Score: {f1_score(y_val, pred_cat, average="macro"):.4f}')
# Out:
# 0:	learn: 2.1709444	total: 283ms	remaining: 1m 24s
# 1:	learn: 1.9606628	total: 532ms	remaining: 1m 19s
# 2:	learn: 1.8076311	total: 762ms	remaining: 1m 15s
# 3:	learn: 1.6818779	total: 979ms	remaining: 1m 12s
# 4:	learn: 1.5694572	total: 1.2s	remaining: 1m 10s
# 5:	learn: 1.4810932	total: 1.43s	remaining: 1m 9s
# 6:	learn: 1.4010845	total: 1.65s	remaining: 1m 9s
# 7:	learn: 1.3282107	total: 1.87s	remaining: 1m 8s
# 8:	learn: 1.2622264	total: 2.09s	remaining: 1m 7s
# 9:	learn: 1.2069576	total: 2.3s	remaining: 1m 6s
# 10:	learn: 1.1507809	total: 2.54s	remaining: 1m 6s
# 11:	learn: 1.1007190	total: 2.77s	remaining: 1m 6s
# 12:	learn: 1.0540135	total: 2.98s	remaining: 1m 5s
# 13:	learn: 1.0082335	total: 3.21s	remaining: 1m 5s
# 14:	learn: 0.9733663	total: 3.42s	remaining: 1m 5s
# 15:	learn: 0.9349446	total: 3.69s	remaining: 1m 5s
# 16:	learn: 0.9005668	total: 3.92s	remaining: 1m 5s
# 17:	learn: 0.8651310	total: 4.13s	remaining: 1m 4s
# 18:	learn: 0.8338033	total: 4.35s	remaining: 1m 4s
# 19:	learn: 0.8053341	total: 4.58s	remaining: 1m 4s
# 20:	learn: 0.7756815	total: 4.88s	remaining: 1m 4s
# 21:	learn: 0.7504141	total: 5.26s	remaining: 1m 6s
# 22:	learn: 0.7261138	total: 5.69s	remaining: 1m 8s
# 23:	learn: 0.7032921	total: 6.11s	remaining: 1m 10s
# 24:	learn: 0.6838090	total: 6.5s	remaining: 1m 11s
# 25:	learn: 0.6636904	total: 6.9s	remaining: 1m 12s
# 26:	learn: 0.6444940	total: 7.32s	remaining: 1m 13s
# 27:	learn: 0.6261672	total: 7.74s	remaining: 1m 15s
# 28:	learn: 0.6084066	total: 8.16s	remaining: 1m 16s
# 29:	learn: 0.5941263	total: 8.55s	remaining: 1m 16s
# 30:	learn: 0.5778135	total: 8.94s	remaining: 1m 17s
# 31:	learn: 0.5626566	total: 9.15s	remaining: 1m 16s
# 32:	learn: 0.5489493	total: 9.37s	remaining: 1m 15s
# 33:	learn: 0.5361080	total: 9.59s	remaining: 1m 15s
# 34:	learn: 0.5233875	total: 9.81s	remaining: 1m 14s
# 35:	learn: 0.5111703	total: 10s	remaining: 1m 13s
# 36:	learn: 0.4995416	total: 10.3s	remaining: 1m 12s
# 37:	learn: 0.4879415	total: 10.5s	remaining: 1m 12s
# 38:	learn: 0.4768718	total: 10.7s	remaining: 1m 11s
# 39:	learn: 0.4641538	total: 10.9s	remaining: 1m 10s
# 40:	learn: 0.4527889	total: 11.1s	remaining: 1m 10s
# 41:	learn: 0.4412602	total: 11.4s	remaining: 1m 9s
# 42:	learn: 0.4327578	total: 11.6s	remaining: 1m 9s
# 43:	learn: 0.4212614	total: 11.8s	remaining: 1m 8s
# 44:	learn: 0.4112790	total: 12s	remaining: 1m 8s
# 45:	learn: 0.4027693	total: 12.3s	remaining: 1m 7s
# 46:	learn: 0.3950152	total: 12.5s	remaining: 1m 7s
# 47:	learn: 0.3872938	total: 12.7s	remaining: 1m 6s
# 48:	learn: 0.3780173	total: 12.9s	remaining: 1m 6s
# 49:	learn: 0.3717295	total: 13.1s	remaining: 1m 5s
# 50:	learn: 0.3652058	total: 13.4s	remaining: 1m 5s
# 51:	learn: 0.3580529	total: 13.6s	remaining: 1m 4s
# 52:	learn: 0.3498096	total: 13.8s	remaining: 1m 4s
# 53:	learn: 0.3433030	total: 14s	remaining: 1m 3s
# 54:	learn: 0.3363491	total: 14.2s	remaining: 1m 3s
# 55:	learn: 0.3305211	total: 14.5s	remaining: 1m 3s
# 56:	learn: 0.3243376	total: 14.7s	remaining: 1m 2s
# 57:	learn: 0.3189085	total: 14.9s	remaining: 1m 2s
# 58:	learn: 0.3142767	total: 15.1s	remaining: 1m 1s
# 59:	learn: 0.3095275	total: 15.3s	remaining: 1m 1s
# 60:	learn: 0.3047866	total: 15.6s	remaining: 1m
# 61:	learn: 0.3001890	total: 15.8s	remaining: 1m
# 62:	learn: 0.2946403	total: 16s	remaining: 1m
# 63:	learn: 0.2896750	total: 16.2s	remaining: 59.9s
# 64:	learn: 0.2848648	total: 16.4s	remaining: 59.5s
# 65:	learn: 0.2806822	total: 16.7s	remaining: 59.1s
# 66:	learn: 0.2763510	total: 16.9s	remaining: 58.7s
# 67:	learn: 0.2720638	total: 17.1s	remaining: 58.3s
# 68:	learn: 0.2671980	total: 17.3s	remaining: 58s
# 69:	learn: 0.2628406	total: 17.5s	remaining: 57.7s
# 70:	learn: 0.2580636	total: 17.8s	remaining: 57.3s
# 71:	learn: 0.2547504	total: 18s	remaining: 56.9s
# 72:	learn: 0.2515804	total: 18.2s	remaining: 56.6s
# 73:	learn: 0.2487968	total: 18.4s	remaining: 56.3s
# 74:	learn: 0.2447036	total: 18.6s	remaining: 55.9s
# 75:	learn: 0.2411671	total: 18.9s	remaining: 55.6s
# 76:	learn: 0.2376239	total: 19.2s	remaining: 55.6s
# 77:	learn: 0.2349853	total: 19.6s	remaining: 55.8s
# 78:	learn: 0.2314327	total: 20s	remaining: 55.9s
# 79:	learn: 0.2280922	total: 20.4s	remaining: 56s
# 80:	learn: 0.2258618	total: 20.7s	remaining: 56.1s
# 81:	learn: 0.2217355	total: 21.2s	remaining: 56.3s
# 82:	learn: 0.2184761	total: 21.6s	remaining: 56.5s
# 83:	learn: 0.2154262	total: 22s	remaining: 56.6s
# 84:	learn: 0.2139867	total: 22.4s	remaining: 56.7s
# 85:	learn: 0.2112390	total: 22.8s	remaining: 56.7s
# 86:	learn: 0.2089865	total: 23.2s	remaining: 56.7s
# 87:	learn: 0.2061623	total: 23.4s	remaining: 56.3s
# 88:	learn: 0.2034770	total: 23.6s	remaining: 55.9s
# 89:	learn: 0.2016564	total: 23.8s	remaining: 55.6s
# 90:	learn: 0.1989866	total: 24s	remaining: 55.2s
# 91:	learn: 0.1973992	total: 24.3s	remaining: 54.8s
# 92:	learn: 0.1953270	total: 24.5s	remaining: 54.5s
# 93:	learn: 0.1923467	total: 24.7s	remaining: 54.1s
# 94:	learn: 0.1898839	total: 24.9s	remaining: 53.8s
# 95:	learn: 0.1880741	total: 25.1s	remaining: 53.4s
# 96:	learn: 0.1860157	total: 25.4s	remaining: 53.1s
# 97:	learn: 0.1837935	total: 25.6s	remaining: 52.7s
# 98:	learn: 0.1819448	total: 25.8s	remaining: 52.4s
# 99:	learn: 0.1795637	total: 26s	remaining: 52.1s
# 100:	learn: 0.1772482	total: 26.3s	remaining: 51.7s
# 101:	learn: 0.1752795	total: 26.5s	remaining: 51.4s
# 102:	learn: 0.1723495	total: 26.7s	remaining: 51s
# 103:	learn: 0.1705211	total: 26.9s	remaining: 50.7s
# 104:	learn: 0.1682197	total: 27.1s	remaining: 50.4s
# 105:	learn: 0.1663088	total: 27.3s	remaining: 50.1s
# 106:	learn: 0.1646786	total: 27.6s	remaining: 49.7s
# 107:	learn: 0.1634343	total: 27.8s	remaining: 49.4s
# 108:	learn: 0.1613756	total: 28s	remaining: 49.1s
# 109:	learn: 0.1602401	total: 28.2s	remaining: 48.8s
# 110:	learn: 0.1586870	total: 28.4s	remaining: 48.4s
# 111:	learn: 0.1573992	total: 28.7s	remaining: 48.1s
# 112:	learn: 0.1560040	total: 28.9s	remaining: 47.8s
# 113:	learn: 0.1549384	total: 29.1s	remaining: 47.5s
# 114:	learn: 0.1534265	total: 29.3s	remaining: 47.2s
# 115:	learn: 0.1516320	total: 29.5s	remaining: 46.9s
# 116:	learn: 0.1499810	total: 29.8s	remaining: 46.5s
# 117:	learn: 0.1478276	total: 30s	remaining: 46.3s
# 118:	learn: 0.1462525	total: 30.2s	remaining: 45.9s
# 119:	learn: 0.1449128	total: 30.4s	remaining: 45.6s
# 120:	learn: 0.1428928	total: 30.6s	remaining: 45.3s
# 121:	learn: 0.1414507	total: 30.9s	remaining: 45s
# 122:	learn: 0.1394229	total: 31.1s	remaining: 44.8s
# 123:	learn: 0.1380465	total: 31.3s	remaining: 44.5s
# 124:	learn: 0.1364199	total: 31.5s	remaining: 44.1s
# 125:	learn: 0.1353490	total: 31.8s	remaining: 43.9s
# 126:	learn: 0.1341485	total: 32s	remaining: 43.6s
# 127:	learn: 0.1327971	total: 32.2s	remaining: 43.3s
# 128:	learn: 0.1317928	total: 32.4s	remaining: 43s
# 129:	learn: 0.1308684	total: 32.6s	remaining: 42.7s
# 130:	learn: 0.1295692	total: 32.9s	remaining: 42.4s
# 131:	learn: 0.1283630	total: 33.1s	remaining: 42.1s
# 132:	learn: 0.1272787	total: 33.5s	remaining: 42s
# 133:	learn: 0.1266175	total: 33.9s	remaining: 42s
# 134:	learn: 0.1247565	total: 34.3s	remaining: 41.9s
# 135:	learn: 0.1237445	total: 34.7s	remaining: 41.8s
# 136:	learn: 0.1230209	total: 35s	remaining: 41.7s
# 137:	learn: 0.1217168	total: 35.4s	remaining: 41.6s
# 138:	learn: 0.1208610	total: 35.9s	remaining: 41.5s
# 139:	learn: 0.1203189	total: 36.3s	remaining: 41.5s
# 140:	learn: 0.1187798	total: 36.7s	remaining: 41.4s
# 141:	learn: 0.1176759	total: 37.1s	remaining: 41.2s
# 142:	learn: 0.1167555	total: 37.5s	remaining: 41.1s
# 143:	learn: 0.1159086	total: 37.7s	remaining: 40.8s
# 144:	learn: 0.1149959	total: 37.9s	remaining: 40.5s
# 145:	learn: 0.1139103	total: 38.1s	remaining: 40.2s
# 146:	learn: 0.1129226	total: 38.3s	remaining: 39.9s
# 147:	learn: 0.1111875	total: 38.6s	remaining: 39.6s
# 148:	learn: 0.1102832	total: 38.8s	remaining: 39.3s
# 149:	learn: 0.1089772	total: 39s	remaining: 39s
# 150:	learn: 0.1078581	total: 39.2s	remaining: 38.7s
# 151:	learn: 0.1065308	total: 39.4s	remaining: 38.4s
# 152:	learn: 0.1052166	total: 39.7s	remaining: 38.1s
# 153:	learn: 0.1041806	total: 39.9s	remaining: 37.8s
# 154:	learn: 0.1031980	total: 40.1s	remaining: 37.5s
# 155:	learn: 0.1027276	total: 40.3s	remaining: 37.2s
# 156:	learn: 0.1020396	total: 40.5s	remaining: 36.9s
# 157:	learn: 0.1013567	total: 40.8s	remaining: 36.7s
# 158:	learn: 0.1007486	total: 41s	remaining: 36.4s
# 159:	learn: 0.0996942	total: 41.2s	remaining: 36.1s
# 160:	learn: 0.0986237	total: 41.4s	remaining: 35.8s
# 161:	learn: 0.0975504	total: 41.7s	remaining: 35.5s
# 162:	learn: 0.0968170	total: 41.9s	remaining: 35.2s
# 163:	learn: 0.0956110	total: 42.1s	remaining: 34.9s
# 164:	learn: 0.0947342	total: 42.3s	remaining: 34.6s
# 165:	learn: 0.0941259	total: 42.6s	remaining: 34.3s
# 166:	learn: 0.0934908	total: 42.8s	remaining: 34.1s
# 167:	learn: 0.0927841	total: 43s	remaining: 33.8s
# 168:	learn: 0.0915497	total: 43.2s	remaining: 33.5s
# 169:	learn: 0.0911104	total: 43.4s	remaining: 33.2s
# 170:	learn: 0.0904839	total: 43.7s	remaining: 32.9s
# 171:	learn: 0.0897240	total: 43.9s	remaining: 32.7s
# 172:	learn: 0.0888774	total: 44.1s	remaining: 32.4s
# 173:	learn: 0.0882990	total: 44.3s	remaining: 32.1s
# 174:	learn: 0.0878594	total: 44.5s	remaining: 31.8s
# 175:	learn: 0.0872235	total: 44.8s	remaining: 31.6s
# 176:	learn: 0.0865868	total: 45s	remaining: 31.3s
# 177:	learn: 0.0859283	total: 45.2s	remaining: 31s
# 178:	learn: 0.0852249	total: 45.4s	remaining: 30.7s
# 179:	learn: 0.0846781	total: 45.7s	remaining: 30.4s
# 180:	learn: 0.0842420	total: 45.9s	remaining: 30.2s
# 181:	learn: 0.0838852	total: 46.1s	remaining: 29.9s
# 182:	learn: 0.0834885	total: 46.3s	remaining: 29.6s
# 183:	learn: 0.0830668	total: 46.5s	remaining: 29.3s
# 184:	learn: 0.0825065	total: 46.8s	remaining: 29.1s
# 185:	learn: 0.0816882	total: 47s	remaining: 28.8s
# 186:	learn: 0.0808580	total: 47.2s	remaining: 28.5s
# 187:	learn: 0.0802967	total: 47.5s	remaining: 28.3s
# 188:	learn: 0.0792606	total: 47.8s	remaining: 28.1s
# 189:	learn: 0.0784621	total: 48.3s	remaining: 28s
# 190:	learn: 0.0775637	total: 48.7s	remaining: 27.8s
# 191:	learn: 0.0769904	total: 49.1s	remaining: 27.6s
# 192:	learn: 0.0759928	total: 49.5s	remaining: 27.4s
# 193:	learn: 0.0754585	total: 49.9s	remaining: 27.3s
# 194:	learn: 0.0746329	total: 50.4s	remaining: 27.1s
# 195:	learn: 0.0741046	total: 50.8s	remaining: 27s
# 196:	learn: 0.0737407	total: 51.2s	remaining: 26.8s
# 197:	learn: 0.0731649	total: 51.6s	remaining: 26.6s
# 198:	learn: 0.0724867	total: 51.8s	remaining: 26.3s
# 199:	learn: 0.0719932	total: 52s	remaining: 26s
# 200:	learn: 0.0716497	total: 52.2s	remaining: 25.7s
# 201:	learn: 0.0711480	total: 52.5s	remaining: 25.5s
# 202:	learn: 0.0707764	total: 52.7s	remaining: 25.2s
# 203:	learn: 0.0705593	total: 52.9s	remaining: 24.9s
# 204:	learn: 0.0702409	total: 53.1s	remaining: 24.6s
# 205:	learn: 0.0698088	total: 53.4s	remaining: 24.4s
# 206:	learn: 0.0692223	total: 53.6s	remaining: 24.1s
# 207:	learn: 0.0686152	total: 53.8s	remaining: 23.8s
# 208:	learn: 0.0678534	total: 54s	remaining: 23.5s
# 209:	learn: 0.0675139	total: 54.2s	remaining: 23.2s
# 210:	learn: 0.0668149	total: 54.5s	remaining: 23s
# 211:	learn: 0.0660377	total: 54.7s	remaining: 22.7s
# 212:	learn: 0.0656364	total: 54.9s	remaining: 22.4s
# 213:	learn: 0.0653604	total: 55.1s	remaining: 22.2s
# 214:	learn: 0.0648364	total: 55.4s	remaining: 21.9s
# 215:	learn: 0.0643100	total: 55.6s	remaining: 21.6s
# 216:	learn: 0.0640773	total: 55.8s	remaining: 21.3s
# 217:	learn: 0.0635527	total: 56s	remaining: 21.1s
# 218:	learn: 0.0632204	total: 56.3s	remaining: 20.8s
# 219:	learn: 0.0628204	total: 56.5s	remaining: 20.5s
# 220:	learn: 0.0622814	total: 56.7s	remaining: 20.3s
# 221:	learn: 0.0619219	total: 56.9s	remaining: 20s
# 222:	learn: 0.0616204	total: 57.1s	remaining: 19.7s
# 223:	learn: 0.0613123	total: 57.4s	remaining: 19.5s
# 224:	learn: 0.0611120	total: 57.6s	remaining: 19.2s
# 225:	learn: 0.0603557	total: 57.8s	remaining: 18.9s
# 226:	learn: 0.0600974	total: 58s	remaining: 18.7s
# 227:	learn: 0.0596075	total: 58.2s	remaining: 18.4s
# 228:	learn: 0.0594174	total: 58.5s	remaining: 18.1s
# 229:	learn: 0.0591627	total: 58.7s	remaining: 17.9s
# 230:	learn: 0.0589180	total: 58.9s	remaining: 17.6s
# 231:	learn: 0.0586242	total: 59.1s	remaining: 17.3s
# 232:	learn: 0.0583699	total: 59.3s	remaining: 17.1s
# 233:	learn: 0.0581255	total: 59.6s	remaining: 16.8s
# 234:	learn: 0.0577537	total: 59.8s	remaining: 16.5s
# 235:	learn: 0.0573403	total: 1m	remaining: 16.3s
# 236:	learn: 0.0570836	total: 1m	remaining: 16s
# 237:	learn: 0.0567928	total: 1m	remaining: 15.7s
# 238:	learn: 0.0561997	total: 1m	remaining: 15.5s
# 239:	learn: 0.0559219	total: 1m	remaining: 15.2s
# 240:	learn: 0.0557603	total: 1m 1s	remaining: 15s
# 241:	learn: 0.0552965	total: 1m 1s	remaining: 14.7s
# 242:	learn: 0.0548399	total: 1m 1s	remaining: 14.4s
# 243:	learn: 0.0546561	total: 1m 1s	remaining: 14.2s
# 244:	learn: 0.0542269	total: 1m 2s	remaining: 14s
# 245:	learn: 0.0538698	total: 1m 2s	remaining: 13.8s
# 246:	learn: 0.0534352	total: 1m 3s	remaining: 13.6s
# 247:	learn: 0.0532158	total: 1m 3s	remaining: 13.3s
# 248:	learn: 0.0530300	total: 1m 3s	remaining: 13.1s
# 249:	learn: 0.0528698	total: 1m 4s	remaining: 12.9s
# 250:	learn: 0.0523647	total: 1m 4s	remaining: 12.6s
# 251:	learn: 0.0521494	total: 1m 5s	remaining: 12.4s
# 252:	learn: 0.0520065	total: 1m 5s	remaining: 12.2s
# 253:	learn: 0.0517447	total: 1m 5s	remaining: 11.9s
# 254:	learn: 0.0511598	total: 1m 6s	remaining: 11.7s
# 255:	learn: 0.0508305	total: 1m 6s	remaining: 11.4s
# 256:	learn: 0.0504631	total: 1m 6s	remaining: 11.1s
# 257:	learn: 0.0502158	total: 1m 6s	remaining: 10.9s
# 258:	learn: 0.0499838	total: 1m 7s	remaining: 10.6s
# 259:	learn: 0.0496652	total: 1m 7s	remaining: 10.3s
# 260:	learn: 0.0491460	total: 1m 7s	remaining: 10.1s
# 261:	learn: 0.0489032	total: 1m 7s	remaining: 9.82s
# 262:	learn: 0.0487605	total: 1m 7s	remaining: 9.55s
# 263:	learn: 0.0484210	total: 1m 8s	remaining: 9.29s
# 264:	learn: 0.0481036	total: 1m 8s	remaining: 9.03s
# 265:	learn: 0.0479078	total: 1m 8s	remaining: 8.77s
# 266:	learn: 0.0477767	total: 1m 8s	remaining: 8.5s
# 267:	learn: 0.0473324	total: 1m 9s	remaining: 8.24s
# 268:	learn: 0.0470733	total: 1m 9s	remaining: 7.98s
# 269:	learn: 0.0466674	total: 1m 9s	remaining: 7.72s
# 270:	learn: 0.0463835	total: 1m 9s	remaining: 7.46s
# 271:	learn: 0.0461794	total: 1m 9s	remaining: 7.2s
# 272:	learn: 0.0459253	total: 1m 10s	remaining: 6.94s
# 273:	learn: 0.0456877	total: 1m 10s	remaining: 6.68s
# 274:	learn: 0.0454135	total: 1m 10s	remaining: 6.42s
# 275:	learn: 0.0451498	total: 1m 10s	remaining: 6.16s
# 276:	learn: 0.0448866	total: 1m 11s	remaining: 5.9s
# 277:	learn: 0.0447523	total: 1m 11s	remaining: 5.64s
# 278:	learn: 0.0444603	total: 1m 11s	remaining: 5.38s
# 279:	learn: 0.0442269	total: 1m 11s	remaining: 5.12s
# 280:	learn: 0.0441063	total: 1m 11s	remaining: 4.86s
# 281:	learn: 0.0439793	total: 1m 12s	remaining: 4.61s
# 282:	learn: 0.0438418	total: 1m 12s	remaining: 4.35s
# 283:	learn: 0.0435907	total: 1m 12s	remaining: 4.09s
# 284:	learn: 0.0433713	total: 1m 12s	remaining: 3.83s
# 285:	learn: 0.0431684	total: 1m 13s	remaining: 3.58s
# 286:	learn: 0.0429747	total: 1m 13s	remaining: 3.32s
# 287:	learn: 0.0427893	total: 1m 13s	remaining: 3.06s
# 288:	learn: 0.0425640	total: 1m 13s	remaining: 2.81s
# 289:	learn: 0.0422683	total: 1m 13s	remaining: 2.55s
# 290:	learn: 0.0419564	total: 1m 14s	remaining: 2.29s
# 291:	learn: 0.0418088	total: 1m 14s	remaining: 2.04s
# 292:	learn: 0.0416317	total: 1m 14s	remaining: 1.78s
# 293:	learn: 0.0414413	total: 1m 14s	remaining: 1.53s
# 294:	learn: 0.0411721	total: 1m 15s	remaining: 1.27s
# 295:	learn: 0.0409841	total: 1m 15s	remaining: 1.02s
# 296:	learn: 0.0407873	total: 1m 15s	remaining: 762ms
# 297:	learn: 0.0405033	total: 1m 15s	remaining: 508ms
# 298:	learn: 0.0402206	total: 1m 15s	remaining: 254ms
# 299:	learn: 0.0399168	total: 1m 16s	remaining: 0us
# CatBoost Macro F1 Score: 0.5911

# %%
# 피처 중요도 추출
ftr_importances_values = cat.feature_importances_
ftr_importances = pd.Series(ftr_importances_values, index=X_train.columns)
ftr_top = ftr_importances.sort_values(ascending=False)

# 피처 중요도 시각화
plt.figure(figsize=(8,6))
plt.title('Feature importances')
sns.barplot(x=ftr_top, y=ftr_top.index)
plt.show()
