# %% [markdown]
# # DATA LOAD

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
from sklearn.metrics import f1_score
import warnings
# %matplotlib inline

warnings.filterwarnings('ignore')

# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.4.0-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.16.4-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.41)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.14.1)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.3)
# Downloading optuna-4.4.0-py3-none-any.whl (395 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 395.9/395.9 kB 6.7 MB/s eta 0:00:00
# Downloading alembic-1.16.4-py3-none-any.whl (247 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.0/247.0 kB 24.4 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, alembic, optuna
# Successfully installed alembic-1.16.4 colorlog-6.9.0 optuna-4.4.0

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.8-cp311-cp311-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.11/dist-packages (from catboost) (0.21)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from catboost) (2.0.2)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.11/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from catboost) (1.15.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (3.2.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->catboost) (8.5.0)
# Downloading catboost-1.2.8-cp311-cp311-manylinux2014_x86_64.whl (99.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 MB 9.7 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.8

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train_df = pd.read_csv('/content/drive/MyDrive/ESAA YB/0_Summer_project/train.csv')
test_df = pd.read_csv('/content/drive/MyDrive/ESAA YB/0_Summer_project/test.csv')

# %%
train_df.head()
# Out:
#             ID         ip_src  port_src          ip_dst  port_dst protocol  \
# 0  TRAIN_00000  192.168.10.18    3721.0  192.168.10.243      55.0      UDP
# 1  TRAIN_00001   192.168.10.5       NaN             NaN      91.0      TCP
# 2  TRAIN_00002   172.16.0.182       NaN   192.168.10.18      83.0      TCP
# 3  TRAIN_00003            NaN   47668.0   192.168.10.18       NaN      TCP
# 4  TRAIN_00004   192.168.10.5   51753.0   151.101.2.116     451.0      TCP
#
#      duration  pkt_count_fwd  pkt_count_bwd  rate_fwd_pkts  ...  \
# 0    0.000231              2              2    8656.974200  ...
# 1    0.000000              0              1       0.000000  ...
# 2    0.606002             11              5      18.151760  ...
# 3    1.003829              6              6       5.977114  ...
# 4  181.195271             62             89            NaN  ...
#
#    rate_bwd_bytes  payload_fwd_mean  payload_bwd_mean  tcp_win_fwd_init  \
# 0    1.142721e+06         81.000000         81.000000                 0
# 1    0.000000e+00          0.000000          0.000000                 0
# 2    1.913360e+04        790.125000        790.125000             29200
# 3    1.155077e+04        993.416667        993.416667             29200
# 4    6.896758e+02               NaN               NaN              8192
#
#    tcp_win_bwd_init  tcp_syn_count  tcp_psh_count  tcp_rst_count  \
# 0                 0              0              0              0
# 1             16392              0              0              0
# 2             28960              2              4              1
# 3             28960              3              2              0
# 4             29200              2             22              0
#
#    iat_avg_packets  attack_type
# 0              NaN       Benign
# 1     1.499097e+09       Benign
# 2     4.040012e-02         Hulk
# 3     9.125718e-02         Hulk
# 4              NaN       Benign
#
# [5 rows x 22 columns]

# %%
test_df.head()
# Out:
#           ID          ip_src  port_src          ip_dst  port_dst protocol  \
# 0  TEST_0000  192.168.10.243   61955.0  192.168.10.249      55.0      UDP
# 1  TEST_0001             NaN   53118.0             NaN    2094.0      TCP
# 2  TEST_0002   192.168.10.43       NaN             NaN      51.0      UDP
# 3  TEST_0003  192.168.10.243   62431.0  192.168.10.249      61.0      UDP
# 4  TEST_0004             NaN   62365.0  192.168.10.249      56.0      UDP
#
#      duration  pkt_count_fwd  pkt_count_bwd  rate_fwd_pkts  ...  \
# 0  351.844741              3              3            NaN  ...
# 1    0.000063              1              1   15887.515152  ...
# 2    0.060045              2              2      33.308350  ...
# 3         NaN              2              2       0.008455  ...
# 4    0.095316              1              1      10.491425  ...
#
#    rate_fwd_bytes  rate_bwd_bytes  payload_fwd_mean  payload_bwd_mean  \
# 0        0.409271        0.719067               NaN               NaN
# 1        0.000000        0.000000              0.00              0.00
# 2     1299.025647     2231.659444             53.00             53.00
# 3        0.384714        0.930079             77.75             77.75
# 4      482.605567     1363.885298             88.00             88.00
#
#    tcp_win_fwd_init  tcp_win_bwd_init  tcp_syn_count  tcp_psh_count  \
# 0                 0                 0              0              0
# 1             29200                 0              1              0
# 2                 0                 0              0              0
# 3                 0                 0              0              0
# 4                 0                 0              0              0
#
#    tcp_rst_count  iat_avg_packets
# 0              0              NaN
# 1              1              NaN
# 2              0         0.020015
# 3              0        78.846374
# 4              0              NaN
#
# [5 rows x 21 columns]

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11999 entries, 0 to 11998
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                11999 non-null  object
#  1   ip_src            9487 non-null   object
#  2   port_src          8625 non-null   float64
#  3   ip_dst            10695 non-null  object
#  4   port_dst          9712 non-null   float64
#  5   protocol          11999 non-null  object
#  6   duration          10925 non-null  float64
#  7   pkt_count_fwd     11999 non-null  int64
#  8   pkt_count_bwd     11999 non-null  int64
#  9   rate_fwd_pkts     10828 non-null  float64
#  10  rate_bwd_pkts     10312 non-null  float64
#  11  rate_fwd_bytes    11999 non-null  float64
#  12  rate_bwd_bytes    11999 non-null  float64
#  13  payload_fwd_mean  10214 non-null  float64
#  14  payload_bwd_mean  10214 non-null  float64
#  15  tcp_win_fwd_init  11999 non-null  int64
#  16  tcp_win_bwd_init  11999 non-null  int64
#  17  tcp_syn_count     11999 non-null  int64
#  18  tcp_psh_count     11999 non-null  int64
#  19  tcp_rst_count     11999 non-null  int64
#  20  iat_avg_packets   9239 non-null   float64
#  21  attack_type       11999 non-null  object
# dtypes: float64(10), int64(7), object(5)
# memory usage: 2.0+ MB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                3000 non-null   object
#  1   ip_src            2363 non-null   object
#  2   port_src          2175 non-null   float64
#  3   ip_dst            2655 non-null   object
#  4   port_dst          2438 non-null   float64
#  5   protocol          3000 non-null   object
#  6   duration          2725 non-null   float64
#  7   pkt_count_fwd     3000 non-null   int64
#  8   pkt_count_bwd     3000 non-null   int64
#  9   rate_fwd_pkts     2672 non-null   float64
#  10  rate_bwd_pkts     2588 non-null   float64
#  11  rate_fwd_bytes    3000 non-null   float64
#  12  rate_bwd_bytes    3000 non-null   float64
#  13  payload_fwd_mean  2536 non-null   float64
#  14  payload_bwd_mean  2536 non-null   float64
#  15  tcp_win_fwd_init  3000 non-null   int64
#  16  tcp_win_bwd_init  3000 non-null   int64
#  17  tcp_syn_count     3000 non-null   int64
#  18  tcp_psh_count     3000 non-null   int64
#  19  tcp_rst_count     3000 non-null   int64
#  20  iat_avg_packets   2311 non-null   float64
# dtypes: float64(10), int64(7), object(4)
# memory usage: 492.3+ KB

# %% [markdown]
# # 전처리

# %%
train = train_df.copy() ## 데이터 복사
test = test_df.copy()

# %% [markdown]
# ## payload 결측치 관련 파생변수

# %%
# payload 결측치 플래그
train['payload_bwd_missing_flag'] = train['payload_bwd_mean'].isna().astype(int)
test['payload_bwd_missing_flag'] = test['payload_bwd_mean'].isna().astype(int)

# %% [markdown]
# ## 결측치 처리

# %%
#=============================================================================
# 포트 변수 변수 => -1
# payload, rate, iat_avg_packets, duration, => 중앙값
#=============================================================================

train['port_src'].fillna(-1, inplace=True) # -1 대체
train['port_dst'].fillna(-1, inplace=True)

payload_bwd_median = train['payload_bwd_mean'].median() # 중앙값 대체
train['payload_bwd_mean'].fillna(payload_bwd_median, inplace=True)

payload_fwd_median = train['payload_fwd_mean'].median()
train['payload_fwd_mean'].fillna(payload_fwd_median, inplace=True)

iat_median = train['iat_avg_packets'].median()
train['iat_avg_packets'].fillna(iat_median, inplace=True)

duration_median = train['duration'].median()
train['duration'].fillna(duration_median, inplace=True)

rate_fwd_median = train['rate_fwd_pkts'].median()
train['rate_fwd_pkts'].fillna(rate_fwd_median, inplace=True)

rate_bwd_median = train['rate_bwd_pkts'].median()
train['rate_bwd_pkts'].fillna(rate_bwd_median, inplace=True)

# %%
test['port_src'].fillna(-1, inplace=True) # -1 대체
test['port_dst'].fillna(-1, inplace=True)

payload_bwd_median = test['payload_bwd_mean'].median() # 중앙값 대체
test['payload_bwd_mean'].fillna(payload_bwd_median, inplace=True)

payload_fwd_median = test['payload_fwd_mean'].median()
test['payload_fwd_mean'].fillna(payload_fwd_median, inplace=True)

iat_median = test['iat_avg_packets'].median()
test['iat_avg_packets'].fillna(iat_median, inplace=True)

duration_median = test['duration'].median()
test['duration'].fillna(duration_median, inplace=True)

rate_fwd_median = test['rate_fwd_pkts'].median()
test['rate_fwd_pkts'].fillna(rate_fwd_median, inplace=True)

rate_bwd_median = test['rate_bwd_pkts'].median()
test['rate_bwd_pkts'].fillna(rate_bwd_median, inplace=True)

# %% [markdown]
# ## 값 기반 범주화 (syn_flag_cat, port_dst_cat)

# %%
#=============================================================================
# tcp_syn_count => 3개로 범주화
# port_dst => 1~2023/이후 상위 5개/나머지
#=============================================================================

def categorize_syn(x):
    if x == 0:
        return 0  # 정상
    elif x in [1, 2]:
        return 1  # 약간의 SYN 요청
    else:
        return 2  # SYN Flooding 가능성

train['syn_flag_cat'] = train['tcp_syn_count'].apply(categorize_syn)
test['syn_flag_cat'] = test['tcp_syn_count'].apply(categorize_syn)

# %%
# port_dst>1023 데이터 중 상위 5개 포트 추출
dst_port_high = train[train['port_dst'] > 1023]['port_dst']
top5_ports = dst_port_high.value_counts().nlargest(5).index

def categorize_port_dst(p):
    if p <= 1023:
        return str(int(p))  # 0~1023은 그대로
    elif p in top5_ports:
        return f'special_{int(p)}' # 1024, 8072, 49152, 8079, 2602
    else:
        return 'other'

train['port_dst_cat'] = train['port_dst'].apply(categorize_port_dst)

# %%
dst_port_high_test = test[test['port_dst'] > 1023]['port_dst']
top5_ports_test = dst_port_high_test.value_counts().nlargest(5).index

def categorize_port_dst_test(p):
    if p <= 1023:
        return str(int(p))  # 0~1023은 그대로
    elif p in top5_ports_test:
        return f'special_{int(p)}' # 1024, 8072, 49152, 8079, 2602
    else:
        return 'other'

test['port_dst_cat'] = test['port_dst'].apply(categorize_port_dst_test)

# %% [markdown]
# ## 추가 파생변수

# %%
# PSH 유무: tcp_psh_count > 0 → 1, else → 0
train['has_psh_flag'] = (train['tcp_psh_count'] > 0).astype(int)
test['has_psh_flag'] = (test['tcp_psh_count'] > 0).astype(int)

# 초당 패킷 전송 비율 = rate_fwd_pkts / rate_bwd_pkts
train['rate_pkts_ratio'] = train['rate_fwd_pkts'] / (train['rate_bwd_pkts'] + 1e-5) # 0으로 나누는 것 방지
test['rate_pkts_ratio'] = test['rate_fwd_pkts'] / (test['rate_bwd_pkts'] + 1e-5)

# 송수신 패킷 비율 = pkt_count_fwd / pkt_count_bwd
train['pkt_count_ratio'] = train['pkt_count_fwd'] / (train['pkt_count_bwd'] + 1e-5)
test['pkt_count_ratio'] = test['pkt_count_fwd'] / (test['pkt_count_bwd'] + 1e-5)

# 패킷 간 평균 시간 간격 이진 파생변수: iat_avg_packets <= 1 → 1, else → 0
train['is_iat_low'] = (train['iat_avg_packets'] <= 1.0).astype(int)
test['is_iat_low'] = (test['iat_avg_packets'] <= 1.0).astype(int)

train.drop(['tcp_psh_count','rate_fwd_pkts','rate_bwd_pkts',
            'pkt_count_fwd','pkt_count_bwd'], axis=1, inplace=True) ## 불필요한 기존변수삭제
test.drop(['tcp_psh_count','rate_fwd_pkts','rate_bwd_pkts',
            'pkt_count_fwd','pkt_count_bwd'], axis=1, inplace=True)

# %% [markdown]
# ## 변수 삭제

# %%
#=============================================================================
# ID, ip_scr, ip_dst, port_src
# payload_fwd_mean (bwd와 겹치는 칼럼)
#=============================================================================

train.drop(['ID','ip_src','ip_dst','payload_fwd_mean','port_src','port_dst','tcp_syn_count'], axis=1, inplace=True)
test.drop(['ID','ip_src','ip_dst','payload_fwd_mean','port_src','port_dst','tcp_syn_count'], axis=1, inplace=True)

# %% [markdown]
# ## 로그변환

# %%
import numpy as np

log_cols = [
    'duration',
    'rate_fwd_bytes',
    'rate_bwd_bytes',
    'payload_bwd_mean',
    'tcp_rst_count',
    'tcp_win_fwd_init',
    'tcp_win_bwd_init',
    'iat_avg_packets',
    'rate_pkts_ratio',
    'pkt_count_ratio' # 파생변수 포함
]

for col in log_cols:
    train[col] = np.log1p(train[col])

for col in log_cols:
    test[col] = np.log1p(test[col])

# %% [markdown]
# ## 스케일링

# %%
from sklearn.preprocessing import StandardScaler

scale_cols = [
    'duration',
    'rate_fwd_bytes',
    'rate_bwd_bytes',
    'payload_bwd_mean',
    'tcp_rst_count',
    'tcp_win_fwd_init',
    'tcp_win_bwd_init',
    'iat_avg_packets',
    'rate_pkts_ratio',
    'pkt_count_ratio'
]

# 스케일러 객체 생성
scaler = StandardScaler()

# 스케일링 적용
train[scale_cols] = scaler.fit_transform(train[scale_cols])
test[scale_cols] = scaler.transform(test[scale_cols])

# %% [markdown]
# ## LabelEncoding

# %%
from sklearn.preprocessing import LabelEncoder

# 라벨 인코더 생성
le_protocol = LabelEncoder()
le_postdst = LabelEncoder()
le_attack = LabelEncoder()

le_protocol.fit(pd.concat([train['protocol'], test['protocol']], axis=0).astype(str).unique())
le_postdst.fit(pd.concat([train['port_dst_cat'], test['port_dst_cat']], axis=0).astype(str).unique())

train['protocol'] = le_protocol.transform(train['protocol'].astype(str))
train['port_dst_cat'] = le_postdst.transform(train['port_dst_cat'].astype(str))
train['attack_type'] = le_attack.fit_transform(train['attack_type']) # attack_type is only in train

test['protocol'] = le_protocol.transform(test['protocol'].astype(str))
test['port_dst_cat'] = le_postdst.transform(test['port_dst_cat'].astype(str))

# %% [markdown]
# ## X, Y 데이터 분리

# %%
# Features
X = train.drop('attack_type',axis=1)

# Target
y = train['attack_type'].values

# %%
# import Library
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=156)

# %% [markdown]
# ## SMOTE + Tomek 적용

# %%
# Import Libraries
from imblearn.combine import SMOTETomek
from imblearn.over_sampling import SMOTE

resampler = SMOTETomek(random_state=156, smote=SMOTE(k_neighbors=3))

X_resampled, y_resampled = resampler.fit_resample(X_train, y_train)

# %% [markdown]
# # 모델링

# %% [markdown]
# ## RandomForest

# %%
# Import Library
from sklearn.ensemble import RandomForestClassifier

# --------------------------------------------------------------------------------

# RandomForestClassifier 객체 생성
rf = RandomForestClassifier(n_estimators=100, random_state=156, n_jobs=-1)

# 학습 및 예측
rf.fit(X_resampled, y_resampled)
pred_rf = rf.predict(X_val)

print(f'랜덤포레스트 Macro F1 Score: {f1_score(y_val, pred_rf, average="macro"):.4f}')
# Out:
# 랜덤포레스트 Macro F1 Score: 0.6805

# %%
# 피처 중요도 추출
ftr_importances_values = rf.feature_importances_
ftr_importances = pd.Series(ftr_importances_values, index=X_train.columns)
ftr_top = ftr_importances.sort_values(ascending=False)

# 피처 중요도 시각화
plt.figure(figsize=(8,6))
plt.title('Feature importances')
sns.barplot(x=ftr_top, y=ftr_top.index)
plt.show()

# %% [markdown]
# #### GridSearchCV를 이용한 하이퍼파라미터 튜닝

# %%
from sklearn.model_selection import GridSearchCV, StratifiedKFold

# --------------------------------------------------------------------------------

skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=156)

param_grid = {
    'max_depth': [5, 10, 15],
    'n_estimators': [100, 200],
    'min_samples_leaf': [1, 5, 10],
    'min_samples_split': [2, 8, 16]
}
grid = GridSearchCV(RandomForestClassifier(random_state=156, n_jobs=-1), param_grid, cv=5)
grid.fit(X_resampled, y_resampled)

# 최적 파라미터로 모델 생성
rf_best = RandomForestClassifier(**grid.best_params_, random_state=156, n_jobs=-1)

rf_best.fit(X_resampled, y_resampled)
pred_rf_best = rf_best.predict(X_val)

print(f'랜덤포레스트 Macro F1 Score: {f1_score(y_val, pred_rf_best, average="macro"):.4f}')
# Out:
# 랜덤포레스트 Macro F1 Score: 0.6818

# %%
# 피처 중요도 추출
ftr_importances_values = rf_best.feature_importances_
ftr_importances = pd.Series(ftr_importances_values, index=X_train.columns)
ftr_top = ftr_importances.sort_values(ascending=False)

# 피처 중요도 시각화
plt.figure(figsize=(8,6))
plt.title('Feature importances')
sns.barplot(x=ftr_top, y=ftr_top.index)
plt.show()

# %% [markdown]
# ## XGBoost

# %%
# Import Library
import xgboost as xgb
from xgboost import XGBClassifier

# --------------------------------------------------------------------------------

# XGBoostClassifier 객체 생성
xgb = XGBClassifier(n_estimators=300, learning_rate=0.05,
                    random_state=156, n_jobs=-1)

# 학습 및 예측
xgb.fit(X_resampled, y_resampled)
pred_xgb = xgb.predict(X_val)

print(f'XGBoost Macro F1 Score: {f1_score(y_val, pred_xgb, average="macro"):.4f}')
# Out:
# XGBoost Macro F1 Score: 0.6851

# %%
# Import Library
from xgboost import plot_importance

# 피처 중요도 시각화
plt.figure(figsize=(8,6))
plot_importance(xgb)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='F score', ylabel='Features'>

# %% [markdown]
# #### Optuna를 이용한 하이퍼파라미터 튜닝

# %%
# Import Libraries
import optuna
from optuna.samplers import TPESampler
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.metrics import make_scorer, f1_score

skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=156)

# objective 함수 생성
def objective(trial):
    params = {
        'colsample_bytree': trial.suggest_categorical('colsample_bytree', [0.5,0.6,0.7,0.8,0.9,1.0]),
        'subsample': trial.suggest_categorical('subsample', [0.5,0.6,0.7,0.8,1.0]),
        'learning_rate': trial.suggest_categorical('learning_rate', [0.005,0.01,0.05,0.1]),
        'n_estimators': trial.suggest_int('n_estimators', 100, 500),
        'max_depth': trial.suggest_categorical('max_depth', [5,7,9,11,13,15]),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 300),
    }

    model = XGBClassifier(**params, random_state=156, n_jobs=-1)
    score = cross_val_score(model, X_resampled, y_resampled, cv=skf, scoring='f1_macro').mean()
    return score

# Optuna 실행
study = optuna.create_study(direction='maximize', sampler=TPESampler(seed=156))
study.optimize(objective, n_trials=50)
# Out:
# [I 2025-07-17 18:08:26,377] A new study created in memory with name: no-name-2d3ebe89-000b-40e0-b864-20dc3dc05b34
# [I 2025-07-17 18:15:36,579] Trial 0 finished with value: 0.981272601550292 and parameters: {'colsample_bytree': 1.0, 'subsample': 0.5, 'learning_rate': 0.01, 'n_estimators': 354, 'max_depth': 13, 'min_child_weight': 81}. Best is trial 0 with value: 0.981272601550292.
# [I 2025-07-17 18:19:50,695] Trial 1 finished with value: 0.9979282943769766 and parameters: {'colsample_bytree': 1.0, 'subsample': 0.8, 'learning_rate': 0.1, 'n_estimators': 208, 'max_depth': 9, 'min_child_weight': 4}. Best is trial 1 with value: 0.9979282943769766.
# [I 2025-07-17 18:29:58,540] Trial 2 finished with value: 0.9742479916067823 and parameters: {'colsample_bytree': 0.6, 'subsample': 0.8, 'learning_rate': 0.005, 'n_estimators': 461, 'max_depth': 13, 'min_child_weight': 159}. Best is trial 1 with value: 0.9979282943769766.
# [I 2025-07-17 18:32:20,291] Trial 3 finished with value: 0.9774587523232627 and parameters: {'colsample_bytree': 0.7, 'subsample': 0.6, 'learning_rate': 0.1, 'n_estimators': 137, 'max_depth': 13, 'min_child_weight': 280}. Best is trial 1 with value: 0.9979282943769766.
# [I 2025-07-17 18:36:07,376] Trial 4 finished with value: 0.9483909307949512 and parameters: {'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.01, 'n_estimators': 162, 'max_depth': 7, 'min_child_weight': 249}. Best is trial 1 with value: 0.9979282943769766.
# [I 2025-07-17 18:43:34,250] Trial 5 finished with value: 0.9901385498601712 and parameters: {'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.1, 'n_estimators': 400, 'max_depth': 5, 'min_child_weight': 198}. Best is trial 1 with value: 0.9979282943769766.
# [I 2025-07-17 18:49:57,591] Trial 6 finished with value: 0.9822308007092492 and parameters: {'colsample_bytree': 0.6, 'subsample': 0.8, 'learning_rate': 0.01, 'n_estimators': 269, 'max_depth': 11, 'min_child_weight': 111}. Best is trial 1 with value: 0.9979282943769766.
# [I 2025-07-17 18:54:38,742] Trial 7 finished with value: 0.9833714740650951 and parameters: {'colsample_bytree': 0.8, 'subsample': 0.8, 'learning_rate': 0.05, 'n_estimators': 204, 'max_depth': 7, 'min_child_weight': 245}. Best is trial 1 with value: 0.9979282943769766.
# [I 2025-07-17 18:57:27,476] Trial 8 finished with value: 0.9911919057993257 and parameters: {'colsample_bytree': 1.0, 'subsample': 0.7, 'learning_rate': 0.1, 'n_estimators': 133, 'max_depth': 9, 'min_child_weight': 121}. Best is trial 1 with value: 0.9979282943769766.
# [I 2025-07-17 19:06:43,595] Trial 9 finished with value: 0.9957800621701278 and parameters: {'colsample_bytree': 1.0, 'subsample': 0.7, 'learning_rate': 0.1, 'n_estimators': 468, 'max_depth': 9, 'min_child_weight': 51}. Best is trial 1 with value: 0.9979282943769766.
# [I 2025-07-17 19:13:04,170] Trial 10 finished with value: 0.9969140809879926 and parameters: {'colsample_bytree': 0.5, 'subsample': 1.0, 'learning_rate': 0.005, 'n_estimators': 263, 'max_depth': 15, 'min_child_weight': 3}. Best is trial 1 with value: 0.9979282943769766.
# [I 2025-07-17 19:19:33,952] Trial 11 finished with value: 0.9973090048982968 and parameters: {'colsample_bytree': 0.5, 'subsample': 1.0, 'learning_rate': 0.005, 'n_estimators': 253, 'max_depth': 15, 'min_child_weight': 1}. Best is trial 1 with value: 0.9979282943769766.
# [I 2025-07-17 19:24:51,369] Trial 12 finished with value: 0.9967706197789831 and parameters: {'colsample_bytree': 0.5, 'subsample': 1.0, 'learning_rate': 0.005, 'n_estimators': 212, 'max_depth': 15, 'min_child_weight': 3}. Best is trial 1 with value: 0.9979282943769766.
# [I 2025-07-17 19:30:47,081] Trial 13 finished with value: 0.9955412290395221 and parameters: {'colsample_bytree': 0.9, 'subsample': 1.0, 'learning_rate': 0.05, 'n_estimators': 321, 'max_depth': 15, 'min_child_weight': 48}. Best is trial 1 with value: 0.9979282943769766.
# [I 2025-07-17 19:35:37,298] Trial 14 finished with value: 0.9835224027819682 and parameters: {'colsample_bytree': 0.5, 'subsample': 0.5, 'learning_rate': 0.005, 'n_estimators': 217, 'max_depth': 9, 'min_child_weight': 36}. Best is trial 1 with value: 0.9979282943769766.
# [I 2025-07-17 19:40:29,877] Trial 15 finished with value: 0.9929996627670166 and parameters: {'colsample_bytree': 0.9, 'subsample': 0.6, 'learning_rate': 0.1, 'n_estimators': 277, 'max_depth': 11, 'min_child_weight': 92}. Best is trial 1 with value: 0.9979282943769766.
# [I 2025-07-17 19:46:30,357] Trial 16 finished with value: 0.9474551856116109 and parameters: {'colsample_bytree': 0.8, 'subsample': 1.0, 'learning_rate': 0.005, 'n_estimators': 334, 'max_depth': 5, 'min_child_weight': 154}. Best is trial 1 with value: 0.9979282943769766.
# [I 2025-07-17 19:50:12,100] Trial 17 finished with value: 0.9952676702931471 and parameters: {'colsample_bytree': 1.0, 'subsample': 0.8, 'learning_rate': 0.05, 'n_estimators': 174, 'max_depth': 9, 'min_child_weight': 26}. Best is trial 1 with value: 0.9979282943769766.
# [I 2025-07-17 19:52:20,856] Trial 18 finished with value: 0.9947072038471859 and parameters: {'colsample_bytree': 0.5, 'subsample': 1.0, 'learning_rate': 0.1, 'n_estimators': 109, 'max_depth': 15, 'min_child_weight': 65}. Best is trial 1 with value: 0.9979282943769766.
# [I 2025-07-17 19:59:55,120] Trial 19 finished with value: 0.9560075574511122 and parameters: {'colsample_bytree': 1.0, 'subsample': 0.8, 'learning_rate': 0.005, 'n_estimators': 380, 'max_depth': 9, 'min_child_weight': 188}. Best is trial 1 with value: 0.9979282943769766.
# [I 2025-07-17 20:04:42,718] Trial 20 finished with value: 0.9966989206069122 and parameters: {'colsample_bytree': 0.5, 'subsample': 0.5, 'learning_rate': 0.1, 'n_estimators': 243, 'max_depth': 15, 'min_child_weight': 20}. Best is trial 1 with value: 0.9979282943769766.
# [I 2025-07-17 20:11:50,030] Trial 21 finished with value: 0.9971176606330628 and parameters: {'colsample_bytree': 0.5, 'subsample': 1.0, 'learning_rate': 0.005, 'n_estimators': 292, 'max_depth': 15, 'min_child_weight': 2}. Best is trial 1 with value: 0.9979282943769766.
# [I 2025-07-17 20:18:45,310] Trial 22 finished with value: 0.9965193297367879 and parameters: {'colsample_bytree': 0.5, 'subsample': 1.0, 'learning_rate': 0.005, 'n_estimators': 295, 'max_depth': 15, 'min_child_weight': 6}. Best is trial 1 with value: 0.9979282943769766.
# [I 2025-07-17 20:24:49,437] Trial 23 finished with value: 0.9855642734482981 and parameters: {'colsample_bytree': 0.5, 'subsample': 1.0, 'learning_rate': 0.005, 'n_estimators': 244, 'max_depth': 15, 'min_child_weight': 70}. Best is trial 1 with value: 0.9979282943769766.
# [I 2025-07-17 20:31:24,475] Trial 24 finished with value: 0.9930326594088161 and parameters: {'colsample_bytree': 0.5, 'subsample': 1.0, 'learning_rate': 0.005, 'n_estimators': 309, 'max_depth': 15, 'min_child_weight': 35}. Best is trial 1 with value: 0.9979282943769766.
# [I 2025-07-17 20:34:41,372] Trial 25 finished with value: 0.9319165662760176 and parameters: {'colsample_bytree': 0.8, 'subsample': 0.6, 'learning_rate': 0.005, 'n_estimators': 176, 'max_depth': 5, 'min_child_weight': 100}. Best is trial 1 with value: 0.9979282943769766.
# [I 2025-07-17 20:39:41,064] Trial 26 finished with value: 0.9903794972763347 and parameters: {'colsample_bytree': 0.6, 'subsample': 0.8, 'learning_rate': 0.01, 'n_estimators': 236, 'max_depth': 11, 'min_child_weight': 52}. Best is trial 1 with value: 0.9979282943769766.
# [I 2025-07-17 20:48:44,454] Trial 27 finished with value: 0.9970561481105369 and parameters: {'colsample_bytree': 0.9, 'subsample': 1.0, 'learning_rate': 0.05, 'n_estimators': 420, 'max_depth': 7, 'min_child_weight': 24}. Best is trial 1 with value: 0.9979282943769766.
# [I 2025-07-17 20:56:41,288] Trial 28 finished with value: 0.9694842030283315 and parameters: {'colsample_bytree': 1.0, 'subsample': 1.0, 'learning_rate': 0.005, 'n_estimators': 351, 'max_depth': 9, 'min_child_weight': 131}. Best is trial 1 with value: 0.9979282943769766.
# [I 2025-07-17 21:03:02,106] Trial 29 finished with value: 0.9768020428149311 and parameters: {'colsample_bytree': 1.0, 'subsample': 0.5, 'learning_rate': 0.01, 'n_estimators': 294, 'max_depth': 15, 'min_child_weight': 83}. Best is trial 1 with value: 0.9979282943769766.
# [I 2025-07-17 21:06:41,122] Trial 30 finished with value: 0.9952559422800926 and parameters: {'colsample_bytree': 0.5, 'subsample': 0.8, 'learning_rate': 0.1, 'n_estimators': 200, 'max_depth': 13, 'min_child_weight': 58}. Best is trial 1 with value: 0.9979282943769766.
# [I 2025-07-17 21:14:10,560] Trial 31 finished with value: 0.997199787831342 and parameters: {'colsample_bytree': 0.9, 'subsample': 1.0, 'learning_rate': 0.05, 'n_estimators': 419, 'max_depth': 7, 'min_child_weight': 21}. Best is trial 1 with value: 0.9979282943769766.
# [I 2025-07-17 21:22:16,270] Trial 32 finished with value: 0.9980954794902284 and parameters: {'colsample_bytree': 0.9, 'subsample': 1.0, 'learning_rate': 0.05, 'n_estimators': 377, 'max_depth': 7, 'min_child_weight': 1}. Best is trial 32 with value: 0.9980954794902284.
# [I 2025-07-17 21:30:13,839] Trial 33 finished with value: 0.9974386413805159 and parameters: {'colsample_bytree': 0.9, 'subsample': 1.0, 'learning_rate': 0.05, 'n_estimators': 440, 'max_depth': 7, 'min_child_weight': 18}. Best is trial 32 with value: 0.9980954794902284.
# [I 2025-07-17 21:39:25,585] Trial 34 finished with value: 0.9951479261268839 and parameters: {'colsample_bytree': 0.9, 'subsample': 0.6, 'learning_rate': 0.05, 'n_estimators': 500, 'max_depth': 7, 'min_child_weight': 43}. Best is trial 32 with value: 0.9980954794902284.
# [I 2025-07-17 21:47:51,040] Trial 35 finished with value: 0.9975696323380998 and parameters: {'colsample_bytree': 0.9, 'subsample': 1.0, 'learning_rate': 0.05, 'n_estimators': 467, 'max_depth': 7, 'min_child_weight': 16}. Best is trial 32 with value: 0.9980954794902284.
# [I 2025-07-17 21:55:55,646] Trial 36 finished with value: 0.9943843913129881 and parameters: {'colsample_bytree': 0.9, 'subsample': 0.8, 'learning_rate': 0.05, 'n_estimators': 453, 'max_depth': 7, 'min_child_weight': 74}. Best is trial 32 with value: 0.9980954794902284.
# [I 2025-07-17 22:02:52,974] Trial 37 finished with value: 0.9973786123367313 and parameters: {'colsample_bytree': 0.9, 'subsample': 1.0, 'learning_rate': 0.05, 'n_estimators': 373, 'max_depth': 7, 'min_child_weight': 16}. Best is trial 32 with value: 0.9980954794902284.
# [I 2025-07-17 22:10:23,466] Trial 38 finished with value: 0.9897595710646044 and parameters: {'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.05, 'n_estimators': 444, 'max_depth': 7, 'min_child_weight': 179}. Best is trial 32 with value: 0.9980954794902284.
# [I 2025-07-17 22:19:23,381] Trial 39 finished with value: 0.9962684688435287 and parameters: {'colsample_bytree': 0.9, 'subsample': 0.8, 'learning_rate': 0.05, 'n_estimators': 500, 'max_depth': 7, 'min_child_weight': 36}. Best is trial 32 with value: 0.9980954794902284.
# [I 2025-07-17 22:27:39,402] Trial 40 finished with value: 0.9885878186628574 and parameters: {'colsample_bytree': 0.9, 'subsample': 1.0, 'learning_rate': 0.05, 'n_estimators': 475, 'max_depth': 13, 'min_child_weight': 284}. Best is trial 32 with value: 0.9980954794902284.
# [I 2025-07-17 22:33:43,230] Trial 41 finished with value: 0.990255230046085 and parameters: {'colsample_bytree': 0.9, 'subsample': 1.0, 'learning_rate': 0.05, 'n_estimators': 379, 'max_depth': 7, 'min_child_weight': 223}. Best is trial 32 with value: 0.9980954794902284.
# [I 2025-07-17 22:41:15,617] Trial 42 finished with value: 0.9974741374922733 and parameters: {'colsample_bytree': 0.9, 'subsample': 1.0, 'learning_rate': 0.05, 'n_estimators': 425, 'max_depth': 7, 'min_child_weight': 17}. Best is trial 32 with value: 0.9980954794902284.
# [I 2025-07-17 22:48:53,484] Trial 43 finished with value: 0.9975458706308572 and parameters: {'colsample_bytree': 0.9, 'subsample': 1.0, 'learning_rate': 0.05, 'n_estimators': 427, 'max_depth': 7, 'min_child_weight': 15}. Best is trial 32 with value: 0.9980954794902284.
# [I 2025-07-17 22:56:14,097] Trial 44 finished with value: 0.995839165741868 and parameters: {'colsample_bytree': 0.9, 'subsample': 0.7, 'learning_rate': 0.05, 'n_estimators': 404, 'max_depth': 7, 'min_child_weight': 33}. Best is trial 32 with value: 0.9980954794902284.
# [I 2025-07-17 23:04:56,363] Trial 45 finished with value: 0.9977251133831377 and parameters: {'colsample_bytree': 0.6, 'subsample': 1.0, 'learning_rate': 0.05, 'n_estimators': 477, 'max_depth': 7, 'min_child_weight': 12}. Best is trial 32 with value: 0.9980954794902284.
# [I 2025-07-17 23:11:27,407] Trial 46 finished with value: 0.9906059248339639 and parameters: {'colsample_bytree': 0.6, 'subsample': 0.5, 'learning_rate': 0.1, 'n_estimators': 394, 'max_depth': 7, 'min_child_weight': 136}. Best is trial 32 with value: 0.9980954794902284.
# [I 2025-07-17 23:21:22,793] Trial 47 finished with value: 0.9917176730628159 and parameters: {'colsample_bytree': 0.6, 'subsample': 0.6, 'learning_rate': 0.01, 'n_estimators': 480, 'max_depth': 7, 'min_child_weight': 48}. Best is trial 32 with value: 0.9980954794902284.
# [I 2025-07-17 23:29:57,270] Trial 48 finished with value: 0.9978085828666116 and parameters: {'colsample_bytree': 0.6, 'subsample': 1.0, 'learning_rate': 0.05, 'n_estimators': 468, 'max_depth': 9, 'min_child_weight': 11}. Best is trial 32 with value: 0.9980954794902284.
# [I 2025-07-17 23:38:10,230] Trial 49 finished with value: 0.9951256018791149 and parameters: {'colsample_bytree': 0.6, 'subsample': 0.8, 'learning_rate': 0.05, 'n_estimators': 467, 'max_depth': 9, 'min_child_weight': 63}. Best is trial 32 with value: 0.9980954794902284.

# %%
# 최적 파라미터 모델 생성
xgb_best = XGBClassifier(**study.best_trial.params, random_state=156, n_jobs=-1)

# 학습 및 예측
xgb_best.fit(X_resampled, y_resampled)
pred_xgb_best = xgb_best.predict(X_val)

print(f'XGBoost Macro F1 Score: {f1_score(y_val, pred_xgb_best, average="macro"):.4f}')
# Out:
# XGBoost Macro F1 Score: 0.6867

# %%
# Import Library
from xgboost import plot_importance

# 피처 중요도 시각화
plt.figure(figsize=(8,6))
plot_importance(xgb)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='F score', ylabel='Features'>

# %% [markdown]
# ## LightGBM

# %%
# Import Library
from lightgbm import LGBMClassifier

# --------------------------------------------------------------------------------

# LightGBM 객체 생성
lgbm = LGBMClassifier(n_estimators=300, learning_rate=0.05,
                      random_state=156, n_jobs=-1, verbose=0)

# 학습 및 예측
lgbm.fit(X_resampled, y_resampled)
pred_lgbm = lgbm.predict(X_val)

print(f'LightGBM Macro F1 Score: {f1_score(y_val, pred_lgbm, average="macro"):.4f}')
# Out:
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# LightGBM Macro F1 Score: 0.7341

# %%
# 피처 중요도 추출
ftr_importances_values = lgbm.feature_importances_
ftr_importances = pd.Series(ftr_importances_values, index=X_train.columns)
ftr_top = ftr_importances.sort_values(ascending=False)

# 피처 중요도 시각화
plt.figure(figsize=(8,6))
plt.title('Feature importances')
sns.barplot(x=ftr_top, y=ftr_top.index)
plt.show()

# %% [markdown]
# ## CatBoost

# %%
# Import Library
from catboost import CatBoostClassifier, Pool

# --------------------------------------------------------------------------------

# CatBoost 객체 생성
cat = CatBoostClassifier(n_estimators=300, learning_rate=0.05, random_state=156)

# 학습 및 예측
cat.fit(X_resampled, y_resampled)
pred_cat = cat.predict(X_val)

print(f'CatBoost Macro F1 Score: {f1_score(y_val, pred_cat, average="macro"):.4f}')
# Out:
# 0:	learn: 2.1753353	total: 475ms	remaining: 2m 22s
# 1:	learn: 1.9682292	total: 862ms	remaining: 2m 8s
# 2:	learn: 1.8119552	total: 1.24s	remaining: 2m 2s
# 3:	learn: 1.6800095	total: 1.58s	remaining: 1m 57s
# 4:	learn: 1.5790494	total: 1.8s	remaining: 1m 46s
# 5:	learn: 1.4928944	total: 2.01s	remaining: 1m 38s
# 6:	learn: 1.4125465	total: 2.24s	remaining: 1m 33s
# 7:	learn: 1.3447133	total: 2.45s	remaining: 1m 29s
# 8:	learn: 1.2729409	total: 2.67s	remaining: 1m 26s
# 9:	learn: 1.2142364	total: 2.88s	remaining: 1m 23s
# 10:	learn: 1.1584563	total: 3.1s	remaining: 1m 21s
# 11:	learn: 1.1074638	total: 3.33s	remaining: 1m 19s
# 12:	learn: 1.0564595	total: 3.54s	remaining: 1m 18s
# 13:	learn: 1.0184698	total: 3.75s	remaining: 1m 16s
# 14:	learn: 0.9794680	total: 3.96s	remaining: 1m 15s
# 15:	learn: 0.9416327	total: 4.18s	remaining: 1m 14s
# 16:	learn: 0.9092610	total: 4.41s	remaining: 1m 13s
# 17:	learn: 0.8825194	total: 4.63s	remaining: 1m 12s
# 18:	learn: 0.8552289	total: 4.84s	remaining: 1m 11s
# 19:	learn: 0.8252773	total: 5.05s	remaining: 1m 10s
# 20:	learn: 0.7939745	total: 5.29s	remaining: 1m 10s
# 21:	learn: 0.7678044	total: 5.51s	remaining: 1m 9s
# 22:	learn: 0.7427388	total: 5.72s	remaining: 1m 8s
# 23:	learn: 0.7195074	total: 5.94s	remaining: 1m 8s
# 24:	learn: 0.6980906	total: 6.15s	remaining: 1m 7s
# 25:	learn: 0.6780977	total: 6.38s	remaining: 1m 7s
# 26:	learn: 0.6567110	total: 6.6s	remaining: 1m 6s
# 27:	learn: 0.6407204	total: 6.82s	remaining: 1m 6s
# 28:	learn: 0.6221199	total: 7.04s	remaining: 1m 5s
# 29:	learn: 0.6079435	total: 7.25s	remaining: 1m 5s
# 30:	learn: 0.5926256	total: 7.49s	remaining: 1m 4s
# 31:	learn: 0.5750314	total: 7.71s	remaining: 1m 4s
# 32:	learn: 0.5594181	total: 7.93s	remaining: 1m 4s
# 33:	learn: 0.5482090	total: 8.14s	remaining: 1m 3s
# 34:	learn: 0.5355087	total: 8.38s	remaining: 1m 3s
# 35:	learn: 0.5234048	total: 8.59s	remaining: 1m 3s
# 36:	learn: 0.5096854	total: 8.81s	remaining: 1m 2s
# 37:	learn: 0.4968970	total: 9.02s	remaining: 1m 2s
# 38:	learn: 0.4865858	total: 9.24s	remaining: 1m 1s
# 39:	learn: 0.4764055	total: 9.47s	remaining: 1m 1s
# 40:	learn: 0.4638106	total: 9.69s	remaining: 1m 1s
# 41:	learn: 0.4527625	total: 9.9s	remaining: 1m
# 42:	learn: 0.4425991	total: 10.1s	remaining: 1m
# 43:	learn: 0.4329313	total: 10.3s	remaining: 1m
# 44:	learn: 0.4241691	total: 10.6s	remaining: 59.9s
# 45:	learn: 0.4152482	total: 10.8s	remaining: 59.5s
# 46:	learn: 0.4070403	total: 11s	remaining: 59.2s
# 47:	learn: 0.3994806	total: 11.2s	remaining: 58.8s
# 48:	learn: 0.3912013	total: 11.4s	remaining: 58.5s
# 49:	learn: 0.3847333	total: 11.7s	remaining: 58.6s
# 50:	learn: 0.3773022	total: 12.1s	remaining: 59.1s
# 51:	learn: 0.3700323	total: 12.5s	remaining: 59.7s
# 52:	learn: 0.3643194	total: 12.9s	remaining: 1m
# 53:	learn: 0.3565094	total: 13.3s	remaining: 1m
# 54:	learn: 0.3506590	total: 13.7s	remaining: 1m 1s
# 55:	learn: 0.3452669	total: 14.1s	remaining: 1m 1s
# 56:	learn: 0.3386099	total: 14.6s	remaining: 1m 2s
# 57:	learn: 0.3334136	total: 15s	remaining: 1m 2s
# 58:	learn: 0.3287021	total: 15.3s	remaining: 1m 2s
# 59:	learn: 0.3239938	total: 15.7s	remaining: 1m 2s
# 60:	learn: 0.3189045	total: 16.1s	remaining: 1m 3s
# 61:	learn: 0.3139553	total: 16.3s	remaining: 1m 2s
# 62:	learn: 0.3072014	total: 16.5s	remaining: 1m 2s
# 63:	learn: 0.3041419	total: 16.7s	remaining: 1m 1s
# 64:	learn: 0.2989512	total: 16.9s	remaining: 1m 1s
# 65:	learn: 0.2950667	total: 17.2s	remaining: 1m
# 66:	learn: 0.2898051	total: 17.4s	remaining: 1m
# 67:	learn: 0.2864431	total: 17.6s	remaining: 1m
# 68:	learn: 0.2817554	total: 17.8s	remaining: 59.6s
# 69:	learn: 0.2776391	total: 18s	remaining: 59.3s
# 70:	learn: 0.2737936	total: 18.3s	remaining: 58.9s
# 71:	learn: 0.2687138	total: 18.5s	remaining: 58.5s
# 72:	learn: 0.2657884	total: 18.7s	remaining: 58.1s
# 73:	learn: 0.2619411	total: 18.9s	remaining: 57.7s
# 74:	learn: 0.2585598	total: 19.1s	remaining: 57.4s
# 75:	learn: 0.2554412	total: 19.3s	remaining: 57s
# 76:	learn: 0.2513645	total: 19.6s	remaining: 56.7s
# 77:	learn: 0.2486063	total: 19.8s	remaining: 56.3s
# 78:	learn: 0.2459324	total: 20s	remaining: 55.9s
# 79:	learn: 0.2425930	total: 20.2s	remaining: 55.6s
# 80:	learn: 0.2402263	total: 20.4s	remaining: 55.2s
# 81:	learn: 0.2360937	total: 20.6s	remaining: 54.9s
# 82:	learn: 0.2329925	total: 20.9s	remaining: 54.5s
# 83:	learn: 0.2307051	total: 21.1s	remaining: 54.2s
# 84:	learn: 0.2274027	total: 21.3s	remaining: 53.9s
# 85:	learn: 0.2248070	total: 21.5s	remaining: 53.5s
# 86:	learn: 0.2216003	total: 21.7s	remaining: 53.2s
# 87:	learn: 0.2185200	total: 21.9s	remaining: 52.9s
# 88:	learn: 0.2148932	total: 22.2s	remaining: 52.6s
# 89:	learn: 0.2126846	total: 22.4s	remaining: 52.2s
# 90:	learn: 0.2091746	total: 22.6s	remaining: 51.9s
# 91:	learn: 0.2063561	total: 22.8s	remaining: 51.6s
# 92:	learn: 0.2036421	total: 23s	remaining: 51.3s
# 93:	learn: 0.2019611	total: 23.3s	remaining: 51s
# 94:	learn: 0.1994440	total: 23.5s	remaining: 50.7s
# 95:	learn: 0.1976097	total: 23.7s	remaining: 50.4s
# 96:	learn: 0.1959177	total: 23.9s	remaining: 50s
# 97:	learn: 0.1933444	total: 24.1s	remaining: 49.7s
# 98:	learn: 0.1908448	total: 24.4s	remaining: 49.5s
# 99:	learn: 0.1892327	total: 24.6s	remaining: 49.1s
# 100:	learn: 0.1869855	total: 24.8s	remaining: 48.8s
# 101:	learn: 0.1847711	total: 25s	remaining: 48.5s
# 102:	learn: 0.1830847	total: 25.2s	remaining: 48.2s
# 103:	learn: 0.1811019	total: 25.4s	remaining: 48s
# 104:	learn: 0.1789103	total: 25.7s	remaining: 47.7s
# 105:	learn: 0.1770454	total: 25.9s	remaining: 47.4s
# 106:	learn: 0.1749041	total: 26.1s	remaining: 47.1s
# 107:	learn: 0.1737062	total: 26.5s	remaining: 47.1s
# 108:	learn: 0.1715836	total: 27.1s	remaining: 47.5s
# 109:	learn: 0.1694786	total: 28.2s	remaining: 48.8s
# 110:	learn: 0.1676621	total: 29.2s	remaining: 49.8s
# 111:	learn: 0.1659790	total: 29.9s	remaining: 50.3s
# 112:	learn: 0.1646768	total: 30.7s	remaining: 50.8s
# 113:	learn: 0.1629287	total: 31.1s	remaining: 50.7s
# 114:	learn: 0.1612047	total: 31.3s	remaining: 50.3s
# 115:	learn: 0.1594062	total: 31.5s	remaining: 50s
# 116:	learn: 0.1585686	total: 31.7s	remaining: 49.6s
# 117:	learn: 0.1572304	total: 31.9s	remaining: 49.3s
# 118:	learn: 0.1553774	total: 32.2s	remaining: 48.9s
# 119:	learn: 0.1539936	total: 32.4s	remaining: 48.6s
# 120:	learn: 0.1526803	total: 32.6s	remaining: 48.2s
# 121:	learn: 0.1515257	total: 32.8s	remaining: 47.9s
# 122:	learn: 0.1503425	total: 33s	remaining: 47.5s
# 123:	learn: 0.1490468	total: 33.2s	remaining: 47.2s
# 124:	learn: 0.1477460	total: 33.5s	remaining: 46.8s
# 125:	learn: 0.1466330	total: 33.7s	remaining: 46.5s
# 126:	learn: 0.1453011	total: 33.9s	remaining: 46.2s
# 127:	learn: 0.1440759	total: 34.1s	remaining: 45.8s
# 128:	learn: 0.1431559	total: 34.3s	remaining: 45.5s
# 129:	learn: 0.1415691	total: 34.5s	remaining: 45.2s
# 130:	learn: 0.1400024	total: 34.8s	remaining: 44.9s
# 131:	learn: 0.1388546	total: 35s	remaining: 44.5s
# 132:	learn: 0.1383537	total: 35.2s	remaining: 44.2s
# 133:	learn: 0.1373469	total: 35.4s	remaining: 43.9s
# 134:	learn: 0.1362822	total: 35.6s	remaining: 43.5s
# 135:	learn: 0.1350789	total: 35.9s	remaining: 43.2s
# 136:	learn: 0.1339539	total: 36.1s	remaining: 42.9s
# 137:	learn: 0.1330514	total: 36.3s	remaining: 42.6s
# 138:	learn: 0.1315348	total: 36.5s	remaining: 42.3s
# 139:	learn: 0.1307641	total: 36.7s	remaining: 42s
# 140:	learn: 0.1292706	total: 36.9s	remaining: 41.7s
# 141:	learn: 0.1285100	total: 37.2s	remaining: 41.3s
# 142:	learn: 0.1275911	total: 37.4s	remaining: 41s
# 143:	learn: 0.1261998	total: 37.6s	remaining: 40.7s
# 144:	learn: 0.1256049	total: 37.8s	remaining: 40.4s
# 145:	learn: 0.1246101	total: 38s	remaining: 40.1s
# 146:	learn: 0.1233209	total: 38.3s	remaining: 39.8s
# 147:	learn: 0.1222017	total: 38.5s	remaining: 39.5s
# 148:	learn: 0.1212049	total: 38.7s	remaining: 39.2s
# 149:	learn: 0.1206251	total: 38.9s	remaining: 38.9s
# 150:	learn: 0.1198989	total: 39.1s	remaining: 38.6s
# 151:	learn: 0.1185181	total: 39.3s	remaining: 38.3s
# 152:	learn: 0.1177608	total: 39.5s	remaining: 38s
# 153:	learn: 0.1169899	total: 39.8s	remaining: 37.7s
# 154:	learn: 0.1159956	total: 40s	remaining: 37.4s
# 155:	learn: 0.1147272	total: 40.2s	remaining: 37.1s
# 156:	learn: 0.1134754	total: 40.4s	remaining: 36.8s
# 157:	learn: 0.1121676	total: 40.8s	remaining: 36.6s
# 158:	learn: 0.1109664	total: 41.2s	remaining: 36.5s
# 159:	learn: 0.1104400	total: 41.6s	remaining: 36.4s
# 160:	learn: 0.1099198	total: 42s	remaining: 36.2s
# 161:	learn: 0.1092439	total: 42.3s	remaining: 36.1s
# 162:	learn: 0.1081750	total: 42.8s	remaining: 35.9s
# 163:	learn: 0.1071718	total: 43.2s	remaining: 35.8s
# 164:	learn: 0.1058936	total: 43.6s	remaining: 35.7s
# 165:	learn: 0.1047680	total: 44s	remaining: 35.5s
# 166:	learn: 0.1041623	total: 44.4s	remaining: 35.4s
# 167:	learn: 0.1034949	total: 44.7s	remaining: 35.1s
# 168:	learn: 0.1026510	total: 44.9s	remaining: 34.8s
# 169:	learn: 0.1020610	total: 45.1s	remaining: 34.5s
# 170:	learn: 0.1014636	total: 45.4s	remaining: 34.2s
# 171:	learn: 0.1007290	total: 45.6s	remaining: 33.9s
# 172:	learn: 0.0997032	total: 45.8s	remaining: 33.6s
# 173:	learn: 0.0989392	total: 46s	remaining: 33.3s
# 174:	learn: 0.0979887	total: 46.2s	remaining: 33s
# 175:	learn: 0.0970028	total: 46.5s	remaining: 32.7s
# 176:	learn: 0.0963624	total: 46.7s	remaining: 32.4s
# 177:	learn: 0.0957096	total: 46.9s	remaining: 32.1s
# 178:	learn: 0.0954058	total: 47.1s	remaining: 31.8s
# 179:	learn: 0.0948163	total: 47.3s	remaining: 31.5s
# 180:	learn: 0.0943073	total: 47.5s	remaining: 31.3s
# 181:	learn: 0.0937761	total: 47.8s	remaining: 31s
# 182:	learn: 0.0932602	total: 48s	remaining: 30.7s
# 183:	learn: 0.0922713	total: 48.2s	remaining: 30.4s
# 184:	learn: 0.0914152	total: 48.4s	remaining: 30.1s
# 185:	learn: 0.0910791	total: 48.6s	remaining: 29.8s
# 186:	learn: 0.0899312	total: 48.8s	remaining: 29.5s
# 187:	learn: 0.0890283	total: 49.1s	remaining: 29.2s
# 188:	learn: 0.0885937	total: 49.3s	remaining: 28.9s
# 189:	learn: 0.0879242	total: 49.5s	remaining: 28.6s
# 190:	learn: 0.0868636	total: 49.7s	remaining: 28.4s
# 191:	learn: 0.0862350	total: 49.9s	remaining: 28.1s
# 192:	learn: 0.0852778	total: 50.1s	remaining: 27.8s
# 193:	learn: 0.0848697	total: 50.4s	remaining: 27.5s
# 194:	learn: 0.0844792	total: 50.6s	remaining: 27.2s
# 195:	learn: 0.0840646	total: 50.8s	remaining: 27s
# 196:	learn: 0.0835682	total: 51s	remaining: 26.7s
# 197:	learn: 0.0828343	total: 51.2s	remaining: 26.4s
# 198:	learn: 0.0822849	total: 51.4s	remaining: 26.1s
# 199:	learn: 0.0818255	total: 51.7s	remaining: 25.8s
# 200:	learn: 0.0814715	total: 51.9s	remaining: 25.6s
# 201:	learn: 0.0804939	total: 52.1s	remaining: 25.3s
# 202:	learn: 0.0799899	total: 52.3s	remaining: 25s
# 203:	learn: 0.0797058	total: 52.5s	remaining: 24.7s
# 204:	learn: 0.0793402	total: 52.8s	remaining: 24.5s
# 205:	learn: 0.0788146	total: 53s	remaining: 24.2s
# 206:	learn: 0.0783237	total: 53.2s	remaining: 23.9s
# 207:	learn: 0.0775210	total: 53.4s	remaining: 23.6s
# 208:	learn: 0.0768398	total: 53.6s	remaining: 23.3s
# 209:	learn: 0.0765039	total: 53.8s	remaining: 23.1s
# 210:	learn: 0.0757990	total: 54.1s	remaining: 22.8s
# 211:	learn: 0.0753059	total: 54.3s	remaining: 22.5s
# 212:	learn: 0.0748220	total: 54.5s	remaining: 22.3s
# 213:	learn: 0.0744554	total: 54.8s	remaining: 22s
# 214:	learn: 0.0739948	total: 55.1s	remaining: 21.8s
# 215:	learn: 0.0736192	total: 55.6s	remaining: 21.6s
# 216:	learn: 0.0732285	total: 56s	remaining: 21.4s
# 217:	learn: 0.0726035	total: 56.4s	remaining: 21.2s
# 218:	learn: 0.0721273	total: 56.8s	remaining: 21s
# 219:	learn: 0.0718371	total: 57.2s	remaining: 20.8s
# 220:	learn: 0.0714912	total: 57.6s	remaining: 20.6s
# 221:	learn: 0.0711783	total: 58s	remaining: 20.4s
# 222:	learn: 0.0708644	total: 58.4s	remaining: 20.2s
# 223:	learn: 0.0705625	total: 58.8s	remaining: 20s
# 224:	learn: 0.0703150	total: 59.1s	remaining: 19.7s
# 225:	learn: 0.0700274	total: 59.3s	remaining: 19.4s
# 226:	learn: 0.0696536	total: 59.5s	remaining: 19.1s
# 227:	learn: 0.0689510	total: 59.7s	remaining: 18.9s
# 228:	learn: 0.0683496	total: 59.9s	remaining: 18.6s
# 229:	learn: 0.0680486	total: 1m	remaining: 18.3s
# 230:	learn: 0.0677754	total: 1m	remaining: 18s
# 231:	learn: 0.0671944	total: 1m	remaining: 17.8s
# 232:	learn: 0.0669498	total: 1m	remaining: 17.5s
# 233:	learn: 0.0665652	total: 1m 1s	remaining: 17.2s
# 234:	learn: 0.0662436	total: 1m 1s	remaining: 16.9s
# 235:	learn: 0.0656466	total: 1m 1s	remaining: 16.7s
# 236:	learn: 0.0653042	total: 1m 1s	remaining: 16.4s
# 237:	learn: 0.0650844	total: 1m 1s	remaining: 16.1s
# 238:	learn: 0.0648537	total: 1m 2s	remaining: 15.9s
# 239:	learn: 0.0644914	total: 1m 2s	remaining: 15.6s
# 240:	learn: 0.0641843	total: 1m 2s	remaining: 15.3s
# 241:	learn: 0.0639800	total: 1m 2s	remaining: 15s
# 242:	learn: 0.0637538	total: 1m 2s	remaining: 14.8s
# 243:	learn: 0.0633697	total: 1m 3s	remaining: 14.5s
# 244:	learn: 0.0631157	total: 1m 3s	remaining: 14.2s
# 245:	learn: 0.0628408	total: 1m 3s	remaining: 14s
# 246:	learn: 0.0625038	total: 1m 3s	remaining: 13.7s
# 247:	learn: 0.0621674	total: 1m 4s	remaining: 13.4s
# 248:	learn: 0.0618581	total: 1m 4s	remaining: 13.2s
# 249:	learn: 0.0615287	total: 1m 4s	remaining: 12.9s
# 250:	learn: 0.0610705	total: 1m 4s	remaining: 12.6s
# 251:	learn: 0.0608649	total: 1m 4s	remaining: 12.4s
# 252:	learn: 0.0606797	total: 1m 5s	remaining: 12.1s
# 253:	learn: 0.0605050	total: 1m 5s	remaining: 11.8s
# 254:	learn: 0.0603287	total: 1m 5s	remaining: 11.6s
# 255:	learn: 0.0600447	total: 1m 5s	remaining: 11.3s
# 256:	learn: 0.0596677	total: 1m 6s	remaining: 11s
# 257:	learn: 0.0594075	total: 1m 6s	remaining: 10.8s
# 258:	learn: 0.0590243	total: 1m 6s	remaining: 10.5s
# 259:	learn: 0.0588963	total: 1m 6s	remaining: 10.3s
# 260:	learn: 0.0586808	total: 1m 6s	remaining: 10s
# 261:	learn: 0.0584889	total: 1m 7s	remaining: 9.79s
# 262:	learn: 0.0583232	total: 1m 7s	remaining: 9.55s
# 263:	learn: 0.0579239	total: 1m 8s	remaining: 9.29s
# 264:	learn: 0.0574640	total: 1m 8s	remaining: 9.08s
# 265:	learn: 0.0572968	total: 1m 9s	remaining: 8.84s
# 266:	learn: 0.0571371	total: 1m 10s	remaining: 8.67s
# 267:	learn: 0.0567458	total: 1m 10s	remaining: 8.44s
# 268:	learn: 0.0562881	total: 1m 11s	remaining: 8.19s
# 269:	learn: 0.0560679	total: 1m 11s	remaining: 7.94s
# 270:	learn: 0.0559153	total: 1m 11s	remaining: 7.7s
# 271:	learn: 0.0556031	total: 1m 12s	remaining: 7.45s
# 272:	learn: 0.0552789	total: 1m 12s	remaining: 7.2s
# 273:	learn: 0.0551480	total: 1m 13s	remaining: 6.94s
# 274:	learn: 0.0550028	total: 1m 13s	remaining: 6.67s
# 275:	learn: 0.0546769	total: 1m 13s	remaining: 6.4s
# 276:	learn: 0.0544288	total: 1m 13s	remaining: 6.13s
# 277:	learn: 0.0542661	total: 1m 14s	remaining: 5.86s
# 278:	learn: 0.0541046	total: 1m 14s	remaining: 5.59s
# 279:	learn: 0.0539572	total: 1m 14s	remaining: 5.32s
# 280:	learn: 0.0536804	total: 1m 14s	remaining: 5.05s
# 281:	learn: 0.0535863	total: 1m 14s	remaining: 4.78s
# 282:	learn: 0.0534281	total: 1m 15s	remaining: 4.51s
# 283:	learn: 0.0530188	total: 1m 15s	remaining: 4.24s
# 284:	learn: 0.0525370	total: 1m 15s	remaining: 3.98s
# 285:	learn: 0.0522727	total: 1m 15s	remaining: 3.71s
# 286:	learn: 0.0520513	total: 1m 15s	remaining: 3.44s
# 287:	learn: 0.0517055	total: 1m 16s	remaining: 3.17s
# 288:	learn: 0.0513665	total: 1m 16s	remaining: 2.91s
# 289:	learn: 0.0509393	total: 1m 16s	remaining: 2.64s
# 290:	learn: 0.0506254	total: 1m 16s	remaining: 2.38s
# 291:	learn: 0.0504690	total: 1m 17s	remaining: 2.11s
# 292:	learn: 0.0501633	total: 1m 17s	remaining: 1.85s
# 293:	learn: 0.0499886	total: 1m 17s	remaining: 1.58s
# 294:	learn: 0.0497270	total: 1m 17s	remaining: 1.32s
# 295:	learn: 0.0495199	total: 1m 17s	remaining: 1.05s
# 296:	learn: 0.0492497	total: 1m 18s	remaining: 790ms
# 297:	learn: 0.0489791	total: 1m 18s	remaining: 526ms
# 298:	learn: 0.0488386	total: 1m 18s	remaining: 263ms
# 299:	learn: 0.0487370	total: 1m 18s	remaining: 0us
# CatBoost Macro F1 Score: 0.6298

# %%
# 피처 중요도 추출
ftr_importances_values = cat.feature_importances_
ftr_importances = pd.Series(ftr_importances_values, index=X_train.columns)
ftr_top = ftr_importances.sort_values(ascending=False)

# 피처 중요도 시각화
plt.figure(figsize=(8,6))
plt.title('Feature importances')
sns.barplot(x=ftr_top, y=ftr_top.index)
plt.show()
